# %%
import pandas as pd

# %%
prev_assoc_table = "/data5/deepro/ukbiobank/papers/bmi_project/4_characterization/protective/data/previous_associations/associations.csv"

# %%
df = pd.read_csv(prev_assoc_table)

# %%
df.loc[df.any_previous_association==True]
# Out:
#                 Gene Gene_symbol                     Group  Giant   gwas  \
# 13   ENSG00000047849        MAP4  white british_high_bmi_3  False   True
# 15   ENSG00000060718     COL11A1  white british_high_bmi_3  False   True
# 25   ENSG00000072518       MARK2  white british_high_bmi_2  False  False
# 33   ENSG00000083807     SLC27A5  white british_high_bmi_2  False  False
# 34   ENSG00000083857        FAT1  white british_high_bmi_3  False   True
# 53   ENSG00000107736       CDH23  white british_high_bmi_3  False   True
# 72   ENSG00000123384        LRP1  white british_high_bmi_3  False   True
# 80   ENSG00000131018       SYNE1  white british_high_bmi_3  False   True
# 83   ENSG00000132677        RHBG  white british_high_bmi_2  False   True
# 101  ENSG00000141458        NPC1  white british_high_bmi_3  False   True
# 107  ENSG00000145934       TENM2  white british_high_bmi_3  False   True
# 110  ENSG00000148219       ASTN2  white british_high_bmi_3  False   True
# ...
