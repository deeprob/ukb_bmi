# %%
import pandas as pd

# %%
enrich_file = "/data5/deepro/ukbiobank/papers/bmi_project/4_characterization/white_british/data/enrichment/gwas_enrichment.csv"

# %%
stats = pd.read_csv(enrich_file)

# %%
stats.loc[stats.FDR<0.05]
# Out:
#                       gwas_phenotype  oddsratio        pvalue  conf_int_lower  \
# 0         gut microbiome measurement   4.134972  6.098362e-07        2.428580
# 1   BMI-adjusted waist circumference   3.161757  4.986423e-06        1.945907
# 2                  urate measurement   2.803471  4.317373e-05        1.709422
# 3             appendicular lean mass   3.052296  4.050080e-05        1.796485
# 4                      periodontitis   6.328278  2.878884e-05        2.779664
# 5     BMI-adjusted hip circumference   2.590879  1.175039e-04        1.596109
# 6               antibody measurement  27.786929  3.316356e-04        4.869349
# 7       Epstein-Barr virus infection  10.184336  2.224329e-04        3.116180
# 8     executive function measurement  27.786929  3.316356e-04        4.869349
# 9   intraocular pressure measurement   3.500983  3.584181e-04        1.750738
# 10                      bone density   3.058626  3.040483e-04        1.655464
# ...

# %%
stats.loc[stats.FDR<0.05]
# Out:
#                         gwas_phenotype  oddsratio        pvalue  \
# 3                          body height   2.187713  1.969847e-04
# 57    intraocular pressure measurement   3.501546  3.584181e-04
# 70                   urate measurement   2.803782  4.317373e-05
# 165               antibody measurement  27.836538  3.316356e-04
# 167         gut microbiome measurement   4.135730  6.098362e-07
# 286                       bone density   3.059050  3.040483e-04
# 356                      periodontitis   6.330441  2.878884e-05
# 397     executive function measurement  27.836538  3.316356e-04
# 769       Epstein-Barr virus infection  10.191276  2.224329e-04
# 826   BMI-adjusted waist circumference   3.162185  4.986423e-06
# 893     BMI-adjusted hip circumference   2.591159  9.650981e-05
# 1069            appendicular lean mass   3.052699  4.050080e-05
#
#       Num_combo_genes_with_phenotype  Num_combo_genes_without_phenotype  \
# ...
