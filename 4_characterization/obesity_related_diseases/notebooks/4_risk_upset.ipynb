# %%
import pandas as pd
import upsetplot

# %%
group_names = ['I10', 'E780', 'R074', 'I251', 'I259', 'E039', 'E11', 'BlockM15-M19', 'K80', 'K81', 'K82', 'F32']
upset_file = "/data5/deepro/ukbiobank/papers/bmi_project/4_characterization/obesity_related_diseases/data/upset_files/risk.csv"
upset_df = pd.read_csv(upset_file).set_index(group_names)

# %%
parsed_upset_df = upset_df.loc[upset_df.counts>0]

# %%
fig = upsetplot.plot(parsed_upset_df.counts, show_counts=True)
