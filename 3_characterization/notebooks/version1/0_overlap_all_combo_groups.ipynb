# %%
import os
import pandas as pd
import upsetplot
from functools import reduce
from itertools import combinations
import seaborn as sns
from matplotlib.ticker import MultipleLocator
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['font.sans-serif'] = "Arial" # missing fonts:: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
matplotlib.rcParams.update({'font.size': 14, 'axes.linewidth': 2, 'xtick.major.width': 1.5, 'xtick.major.size': 7, 'ytick.major.width': 1.5, 'ytick.major.size': 7})
from matplotlib.backends.backend_pdf import PdfPages

# %%
def save_pdf(save_file, fig):
    pdf = PdfPages(save_file)
    pdf.savefig(fig, bbox_inches='tight',dpi=300)
    pdf.close()
    return

# %%
combo_dir = "/data6/deepro/ukb_bmi/2_rarecomb/data"
group_names = ["british", "british_male", "british_female", "pre_menopause", "post_menopause", ] # "protective"

# %%
def get_combo_set(combo_dir, group):
    combo2_file = os.path.join(combo_dir, group, "combo2.csv")
    combo3_file = os.path.join(combo_dir, group, "combo3.csv")
    try:
        combo2_df = pd.read_csv(combo2_file, usecols=["uniq_items"])
        combo2_set = set(combo2_df.uniq_items.to_list())
    except FileNotFoundError:
        combo2_set = set()
    try:
        combo3_df = pd.read_csv(combo3_file, usecols=["uniq_items"])
        combo3_set = set(combo3_df.uniq_items.to_list())
    except FileNotFoundError:
        combo3_set =set()
    combo_set = combo2_set.union(combo3_set)
    return combo_set

# %%
def set_add(a, b):
    return a.intersection(b)

def set_subtract(a,b):
    return a.difference(b)

def get_intersects(include_sets, exclude_sets):
    intersect_sets = reduce(set_add, include_sets)
    if len(exclude_sets)>0:
        exclude_sets = [intersect_sets] + exclude_sets
        intersect_sets = reduce(set_subtract, exclude_sets)
    return intersect_sets

def get_upset_df(combo_dir, groups):
    # get the set of gene combinations for each group
    combo_dict = {g: get_combo_set(combo_dir, g) for g in groups}
    combo_boolean_dict = {g:[] for g in groups}
    counts = []
    unique_intersect_sets = dict()
    for i in range(1, len(groups) + 1):
        # get combinations of length i
        all_combos = list(combinations(groups, i))
        for combos in all_combos:
            # get counts of elements that are unique to the combinations
            include_combos = combos
            exclude_combos = tuple(g for g in groups if g not in include_combos)
            include_sets = [combo_dict[c] for c in include_combos]
            exclude_sets = [combo_dict[c] for c in exclude_combos]
            unique_intersects = get_intersects(include_sets, exclude_sets)
            counts.append(len(unique_intersects))
            unique_intersect_sets[(include_combos, exclude_combos)] = unique_intersects
            for c in include_combos:
                combo_boolean_dict[c].append(True)
            for c in exclude_combos:
                combo_boolean_dict[c].append(False)
    combo_boolean_dict["counts"] = counts
    df = pd.DataFrame(combo_boolean_dict)
    return df.set_index(groups), unique_intersect_sets

# %%
upset_df, unique_intersects = get_upset_df(combo_dir, group_names)

# %%
parsed_upset_df = upset_df.loc[upset_df.counts>0]

# %%
fig,ax = plt.subplots(1,1, figsize=(12, 6))
upsetplot.plot(parsed_upset_df.counts, show_counts=True, fig=fig, element_size=None)
ax.axis("off")
# Out:
# /data6/deepro/miniconda3/envs/dnanexus/lib/python3.11/site-packages/upsetplot/plotting.py:662: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['black' '#0000002e' '#0000002e' '#0000002e' '#0000002e' '#0000002e'
#  'black' '#0000002e' '#0000002e' '#0000002e' '#0000002e' '#0000002e'
#  'black' '#0000002e' '#0000002e' '#0000002e' '#0000002e' '#0000002e'
#  'black' '#0000002e' '#0000002e' '#0000002e' '#0000002e' '#0000002e'
#  'black' 'black' 'black' '#0000002e' '#0000002e' '#0000002e' 'black'
#  '#0000002e' 'black' '#0000002e' '#0000002e' 'black' '#0000002e'
#  '#0000002e' 'black' '#0000002e' '#0000002e' '#0000002e' 'black' 'black'
#  '#0000002e' '#0000002e' '#0000002e' '#0000002e' 'black' 'black' 'black'
#  '#0000002e' 'black' 'black' '#0000002e']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /data6/deepro/miniconda3/envs/dnanexus/lib/python3.11/site-packages/upsetplot/plotting.py:663: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'solid' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   styles["linestyle"].fillna("solid", inplace=True)
# (0.0, 1.0, 0.0, 1.0)

# %%
save_file = "/data6/deepro/ukb_bmi/3_characterization/data/shared/overlap_combos.pdf"
save_pdf(save_file, fig)

# %%
unique_intersects
# Out:
# {(('british',),
#   ('british_male',
#    'british_female',
#    'pre_menopause',
#    'post_menopause')): {'Input_RANBP6|Input_ZEB2',
#   'Input_RGS9|Input_VSX1',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGB2',
#   'Input_CACNA1S|Input_MYOM2|Input_TTN',
#   'Input_LRP2|Input_MYO7A|Input_PDPR',
#   'Input_SPINK5|Input_TLX1',
#   'Input_HMGCR|Input_UGT1A6|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA4',
#   'Input_ABCA7|Input_ITPR3|Input_PKHD1L1',
#   'Input_ARHGAP22|Input_PBX3',
#   'Input_DPY19L2|Input_OBSL1',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGA6',
#   'Input_CPB2|Input_SMAD1',
#   'Input_DHRS4L2|Input_UGT1A4|Input_UGT1A9',
#   'Input_SPINK5|Input_UGT1A5|Input_UGT1A8',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGB5',
#   'Input_PAFAH2|Input_TRPV4',
#   'Input_ALS2|Input_FAP',
#   'Input_DHRS4L2|Input_UGT1A1|Input_UGT1A6',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA7',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGB6',
#   'Input_FBN2|Input_PCDHGB2|Input_PCDHGB7',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGB6',
#   'Input_EHMT1|Input_MGST2',
#   'Input_CDH5|Input_PCDHB12',
#   'Input_ABCA4|Input_OBSCN|Input_SCN10A',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGB4',
#   'Input_ABCB4|Input_UGT1A1|Input_UGT1A5',
#   'Input_ITGA11|Input_PPP2CB',
#   'Input_SI|Input_TENM4|Input_TULP2',
#   'Input_ABCC12|Input_COL17A1|Input_RYR2',
#   'Input_EXOSC9|Input_ZNF883',
#   'Input_ABCB4|Input_UGT1A4|Input_UGT1A5',
#   'Input_CLCNKA|Input_SCN7A|Input_TTN',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA2',
#   'Input_FBN2|Input_PCDHGA8|Input_PCDHGC3',
#   'Input_SPINK5|Input_UGT1A3|Input_UGT1A6',
#   'Input_SPINK5|Input_UGT1A4|Input_UGT1A5',
#   'Input_SPIDR|Input_UGT1A5|Input_UGT1A7',
#   'Input_COL6A3|Input_FER1L6|Input_PKHD1L1',
#   'Input_CHRNB3|Input_CRYGC',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA6',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGB4',
#   'Input_DCAF13|Input_NIM1K',
#   'Input_CACNA1H|Input_MGAM|Input_MYH7B',
#   'Input_ACE|Input_EHBP1L1|Input_SCN10A',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGB6',
#   'Input_KIF5C|Input_RFC1',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGA7',
#   'Input_ABCC8|Input_HELZ|Input_TTN',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGA8',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGC5',
#   'Input_HMGCR|Input_UGT1A10|Input_UGT1A9',
#   'Input_HOXC12|Input_UGT1A3|Input_UGT1A8',
#   'Input_CLPTM1L|Input_NOTCH3',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGB3',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A10',
#   'Input_IDS|Input_METTL8',
#   'Input_FBN2|Input_PCDHGA9|Input_PCDHGC4',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGB2',
#   'Input_ASXL3|Input_POLI|Input_TENM4',
#   'Input_FBN2|Input_PCDHGB6|Input_PCDHGC4',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGC5',
#   'Input_CPSF1|Input_VIL1',
#   'Input_CCT4|Input_SCARB1',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGB3',
#   'Input_DHRS4L2|Input_UGT1A6|Input_UGT1A9',
#   'Input_SPINK5|Input_UGT1A1|Input_UGT1A6',
#   'Input_HMCN1|Input_RANBP17|Input_TTN',
#   'Input_DHRS4L2|Input_UGT1A7|Input_UGT1A9',
#   'Input_GIT1|Input_SGCA',
#   'Input_KRT222|Input_PPARD',
#   'Input_ATP8B1|Input_VWA5B2',
#   'Input_HOXB1|Input_UGT1A5|Input_UGT1A7',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGA8',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGB5',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGB3',
#   'Input_CAD|Input_SI|Input_TTN',
#   'Input_HOXB1|Input_UGT1A10|Input_UGT1A5',
#   'Input_ABCA4|Input_MYO1F|Input_TTN',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGA9',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGB4',
#   'Input_CAPN8|Input_CHRND',
#   'Input_ECEL1|Input_PCDHGB2|Input_PCDHGB6',
#   'Input_HOXC12|Input_UGT1A8',
#   'Input_KIF26B|Input_MEGF6|Input_TTN',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGA6',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA9',
#   'Input_MYH7B|Input_MYO7A|Input_SPTBN5',
#   'Input_CNGB1|Input_MGAT1',
#   'Input_LRP2|Input_PKLR|Input_RYR3',
#   'Input_ECEL1|Input_PCDHGC4|Input_PCDHGC5',
#   'Input_SLC4A9|Input_UGT1A10|Input_UGT1A7',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGA7',
#   'Input_HCN4|Input_UGT2A1|Input_UGT2A2',
#   'Input_ATP2A3|Input_DNAH5|Input_DYSF',
#   'Input_ECEL1|Input_PCDHGB5|Input_PCDHGC3',
#   'Input_FBN2|Input_PCDHGB1|Input_PCDHGB2',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA12',
#   'Input_LRRC55|Input_PAH',
#   'Input_HOXB1|Input_UGT1A10|Input_UGT1A7',
#   'Input_ARVCF|Input_GDF9',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGA6',
#   'Input_ARSK|Input_LRP2|Input_NEFM',
#   'Input_CFTR|Input_FLNC|Input_NPC1',
#   'Input_MCAT|Input_SACS',
#   'Input_ABCC2|Input_CFTR|Input_LRP2',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGA11',
#   'Input_ALDH5A1|Input_DDR1',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGC5',
#   'Input_SPIDR|Input_UGT1A7|Input_UGT1A8',
#   'Input_ABCA4|Input_MYO7A|Input_NELL1',
#   'Input_AMN|Input_ZNF648',
#   'Input_KRT76|Input_MTA3',
#   'Input_DHRS4L2|Input_UGT1A3|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA6',
#   'Input_FAM241A|Input_PAX4',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGB7',
#   'Input_DNAH5|Input_ST3GAL5',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA8',
#   'Input_ABCB4|Input_UGT1A10|Input_UGT1A6',
#   'Input_ABCA13|Input_MYO7A|Input_OBSCN',
#   'Input_AP3D1|Input_TMPRSS6',
#   'Input_FLNB|Input_GRM8|Input_TTN',
#   'Input_FERMT3|Input_SPTBN2',
#   'Input_FARP1|Input_RPAP3',
#   'Input_POTEE|Input_POTEF|Input_STAB1',
#   'Input_CST8|Input_EIF6',
#   'Input_BRCA1|Input_SSMEM1',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGB7',
#   'Input_SPINK5|Input_UGT1A7|Input_UGT1A8',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGB1',
#   'Input_CEP95|Input_DTNB',
#   'Input_ACMSD|Input_CACNA1H',
#   'Input_DNAH5|Input_GRM6|Input_SACS',
#   'Input_FRMD7|Input_PEAR1|Input_POLI',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGA8',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGA8',
#   'Input_INPP5J|Input_ZMPSTE24',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGB4',
#   'Input_ATP7B|Input_COL16A1|Input_NOTCH1',
#   'Input_ECEL1|Input_PCDHGB6|Input_PCDHGB7',
#   'Input_CLCN6|Input_EPHA6',
#   'Input_LRP1B|Input_MCM5',
#   'Input_CPA4|Input_TSR3',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGA4',
#   'Input_DHRS4L2|Input_UGT1A1|Input_UGT1A7',
#   'Input_IQCC|Input_MYH4|Input_TTN',
#   'Input_CACNA1D|Input_CYP4B1',
#   'Input_ABCA4|Input_SLC7A2|Input_TTN',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGA9',
#   'Input_PAPSS2|Input_POPDC2',
#   'Input_CNGA1|Input_SLC25A45',
#   'Input_SPINK5|Input_UGT1A10|Input_UGT1A4',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA11',
#   'Input_CDH23|Input_KRT35|Input_KRT39',
#   'Input_HOXC12|Input_UGT1A3|Input_UGT1A7',
#   'Input_DNPEP|Input_KLK12',
#   'Input_EFL1|Input_FLT3',
#   'Input_DEFB108B|Input_KLC2',
#   'Input_CYP4F22|Input_ZNF490|Input_ZNF69',
#   'Input_PPP1R15A|Input_PXN',
#   'Input_FGF3|Input_TRIM65',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGB2',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGA6',
#   'Input_AATF|Input_BSN',
#   'Input_AOC2|Input_OR52K1',
#   'Input_LRRK1|Input_SLC25A13',
#   'Input_ECEL1|Input_PCDHGC3|Input_PCDHGC4',
#   'Input_GUCY1A1|Input_NIM1K',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGB3',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGB6',
#   'Input_HOXB1|Input_UGT1A4|Input_UGT1A8',
#   'Input_ARHGEF12|Input_DARS1',
#   'Input_ABCC1|Input_RYR1|Input_TNS1',
#   'Input_AGER|Input_TNS3',
#   'Input_HHATL|Input_SAMD15',
#   'Input_BSND|Input_CLDN18',
#   'Input_GJB4|Input_MAVS',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGB7',
#   'Input_ATP7B|Input_PCDHGA11|Input_PCDHGA3',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGC4',
#   'Input_ISOC2|Input_MYO1G',
#   'Input_ACACB|Input_CFTR|Input_MYH7B',
#   'Input_HECTD3|Input_NAPRT',
#   'Input_GJB5|Input_SUCLA2',
#   'Input_SLC4A9|Input_UGT1A1|Input_UGT1A3',
#   'Input_CLCA2|Input_GBP6',
#   'Input_HMGCR|Input_UGT1A1|Input_UGT1A7',
#   'Input_GADL1|Input_OXSM',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGA6',
#   'Input_DCLRE1C|Input_SOX6',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGC5',
#   'Input_SLC4A10|Input_VWA1',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGB2',
#   'Input_SPINK5|Input_UGT1A7|Input_UGT1A9',
#   'Input_APP|Input_NDUFA13',
#   'Input_EP400|Input_FLNB|Input_RYR3',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A4',
#   'Input_ECEL1|Input_PCDHGA9|Input_PCDHGB5',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGB7',
#   'Input_GANC|Input_TGFBR2',
#   'Input_GSDME|Input_RDH16',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA5',
#   'Input_ABCA13|Input_COL6A3|Input_MYO7A',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGC3',
#   'Input_HMGCR|Input_UGT1A3|Input_UGT1A5',
#   'Input_ECEL1|Input_PCDHGB7|Input_PCDHGC5',
#   'Input_FKRP|Input_HHATL',
#   'Input_DNAH1|Input_XRRA1',
#   'Input_HOXB1|Input_UGT1A5|Input_UGT1A8',
#   'Input_FMO2|Input_TTLL5',
#   'Input_MAN2A2|Input_SBNO2',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGC5',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA5',
#   'Input_FBN2|Input_PCDHGB2|Input_PCDHGB5',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGB4',
#   'Input_ABCB4|Input_UGT1A1|Input_UGT1A10',
#   'Input_GATB|Input_PRRC1',
#   'Input_HSPG2|Input_PYGM|Input_RYR1',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGB1',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGA9',
#   'Input_RYR3|Input_SLC45A2|Input_TENM4',
#   'Input_COL4A2|Input_IGFBP1',
#   'Input_CFTR|Input_FLNC|Input_UGT2A1',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGA8',
#   'Input_FBN2|Input_PCDHGA9|Input_PCDHGB1',
#   'Input_KLK1|Input_TRIM55',
#   'Input_DNAH7|Input_SCN5A|Input_WFS1',
#   'Input_SPINK5|Input_UGT1A10|Input_UGT1A5',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGC5',
#   'Input_ATP7B|Input_GRIN2C|Input_TTN',
#   'Input_HMGCR|Input_UGT1A1|Input_UGT1A9',
#   'Input_ATP7B|Input_PCDHGA2|Input_PCDHGA3',
#   'Input_CRYBG1|Input_LRP2|Input_TTN',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGC5',
#   'Input_UBE2N|Input_VEPH1',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGC3',
#   'Input_FKTN|Input_PRKG1',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA5',
#   'Input_NOTCH3|Input_TENM4|Input_TTN',
#   'Input_ABCC1|Input_ATL1',
#   'Input_FTCD|Input_RABL2A',
#   'Input_RAD50|Input_STK11IP',
#   'Input_MMP3|Input_NOS1',
#   'Input_RUSF1|Input_TENM4',
#   'Input_OTOF|Input_POLQ|Input_SCN11A',
#   'Input_PSEN2|Input_RYR3|Input_TNS1',
#   'Input_CXADR|Input_SLC47A1',
#   'Input_CORO1B|Input_CTSW',
#   'Input_SPIDR|Input_UGT1A10|Input_UGT1A5',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGB2',
#   'Input_HMGCR|Input_UGT1A4|Input_UGT1A7',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGB3',
#   'Input_ENPP5|Input_FOXI1',
#   'Input_NRAP|Input_SPTB',
#   'Input_ECEL1|Input_PCDHGB7|Input_PCDHGC3',
#   'Input_SLC26A8|Input_SOSTDC1',
#   'Input_ECEL1|Input_PCDHGA8|Input_PCDHGA9',
#   'Input_ASS1|Input_CDC42EP5',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGB1',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A3',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGA8',
#   'Input_ALDH1L1|Input_EFCC1',
#   'Input_FBN2|Input_PCDHGA8|Input_PCDHGB3',
#   'Input_SPIDR|Input_UGT1A3|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGC3',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGA4',
#   'Input_AFP|Input_MMADHC',
#   'Input_MYH8|Input_PKHD1L1|Input_RYR2',
#   'Input_GSDME|Input_SCN7A',
#   'Input_CCDC7|Input_RND1',
#   'Input_BACE1|Input_TOP2A',
#   'Input_DHTKD1|Input_SLC25A15',
#   'Input_COL5A1|Input_DYSF|Input_TENM4',
#   'Input_HOXB1|Input_UGT1A10|Input_UGT1A6',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA8',
#   'Input_GOPC|Input_SLC11A2',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGB3',
#   'Input_FBN2|Input_PCDHGA7|Input_PCDHGC4',
#   'Input_GSS|Input_IFNK',
#   'Input_HES4|Input_TP53',
#   'Input_MYH13|Input_PKHD1L1|Input_TTN',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGC3',
#   'Input_METTL4|Input_SLIT2',
#   'Input_PKHD1L1|Input_TTN|Input_VWDE',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA2',
#   'Input_ABCB4|Input_UGT1A6|Input_UGT1A8',
#   'Input_KCNH6|Input_TOE1',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA4',
#   'Input_HOXC12|Input_UGT1A1|Input_UGT1A3',
#   'Input_ATIC|Input_FLNB|Input_RYR2',
#   'Input_DHRS4L2|Input_UGT1A10|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGC5',
#   'Input_FBN2|Input_PCDHGB7|Input_PCDHGC3',
#   'Input_DNAH3|Input_LDLR|Input_TTN',
#   'Input_HMGCR|Input_UGT1A7|Input_UGT1A9',
#   'Input_ABCC10|Input_MYH6|Input_SCN11A',
#   'Input_DHRS4L2|Input_UGT1A1|Input_UGT1A5',
#   'Input_ABCB4|Input_UGT1A3|Input_UGT1A5',
#   'Input_CYP4F2|Input_DNAH14',
#   'Input_SLC4A9|Input_UGT1A10|Input_UGT1A9',
#   'Input_ABCC1|Input_ATP7B|Input_RYR3',
#   'Input_ATAD3B|Input_C14orf28',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGB5',
#   'Input_ABCB4|Input_UGT1A1|Input_UGT1A4',
#   'Input_APOE|Input_KRT71',
#   'Input_ECEL1|Input_PCDHGB3|Input_PCDHGB7',
#   'Input_C22orf15|Input_SLC25A10',
#   'Input_CPT1B|Input_DRG1|Input_SFI1',
#   'Input_LRP1|Input_TTN|Input_ZRANB3',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGB6',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGB5',
#   'Input_POTEE|Input_PPP5C',
#   'Input_HMGCR|Input_UGT1A1|Input_UGT1A3',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGC4',
#   'Input_DYNC1I1|Input_GIMAP2',
#   'Input_CACNA1A|Input_RNMT',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGB1',
#   'Input_DUOX1|Input_GLDC|Input_RYR3',
#   'Input_F5|Input_RYR2|Input_SCN10A',
#   'Input_ABCB4|Input_UGT1A1|Input_UGT1A7',
#   'Input_ECEL1|Input_PCDHGA8|Input_PCDHGB2',
#   'Input_INSRR|Input_MYH6|Input_RYR3',
#   'Input_HOXC12|Input_UGT1A10|Input_UGT1A9',
#   'Input_SPIDR|Input_UGT1A4|Input_UGT1A9',
#   'Input_CACNA1H|Input_FBN3|Input_TENM3',
#   'Input_HOXB1|Input_UGT1A6|Input_UGT1A8',
#   'Input_ABCC10|Input_SLC22A7|Input_UBR4',
#   'Input_MYH1|Input_MYO7A|Input_TPCN2',
#   'Input_MMP24|Input_MYO5C',
#   'Input_HOXB1|Input_UGT1A7|Input_UGT1A9',
#   'Input_BLTP2|Input_ISM2',
#   'Input_STXBP2|Input_ZNF717',
#   'Input_ABCC2|Input_HYAL2',
#   'Input_ERICH3|Input_POLRMT',
#   'Input_ACTR6|Input_PCDH8',
#   'Input_SPIDR|Input_UGT1A7|Input_UGT1A9',
#   'Input_HOXB1|Input_UGT1A1|Input_UGT1A3',
#   'Input_GAA|Input_RYR3|Input_SCN10A',
#   'Input_TRMT5|Input_TTC39B',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGC4',
#   'Input_CORO2A|Input_MRPL33',
#   'Input_ATF1|Input_ITIH2',
#   'Input_ARSI|Input_SLC9A5',
#   'Input_ABCC1|Input_CFTR|Input_TENM4',
#   'Input_CHD6|Input_FLNB|Input_SCN10A',
#   'Input_HOXB1|Input_UGT1A3|Input_UGT1A4',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGB2',
#   'Input_KRT36|Input_MYOF|Input_OTOF',
#   'Input_MFSD12|Input_TENM4|Input_TTN',
#   'Input_DHRS4L2|Input_UGT1A7|Input_UGT1A8',
#   'Input_CASQ1|Input_KRT25',
#   'Input_ATP12A|Input_DNAH5|Input_LRP2',
#   'Input_ALMS1|Input_PKHD1',
#   'Input_FBN2|Input_PCDHGA7|Input_PCDHGC5',
#   'Input_ASGR1|Input_MASP1',
#   'Input_ABCB4|Input_UGT1A7|Input_UGT1A8',
#   'Input_HMGCR|Input_UGT1A4|Input_UGT1A5',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGB5',
#   'Input_ATP7B|Input_PCDHGA2|Input_PCDHGB4',
#   'Input_ACACB|Input_PLEC|Input_TENM4',
#   'Input_ALPI|Input_CSNK1A1L',
#   'Input_HOXB1|Input_UGT1A6|Input_UGT1A7',
#   'Input_CORO2A|Input_SPDYA',
#   'Input_CNGA3|Input_CSTA',
#   'Input_IFITM2|Input_PGAP2',
#   'Input_SLC4A9|Input_UGT1A1|Input_UGT1A4',
#   'Input_CROT|Input_LRP2|Input_TENM4',
#   'Input_ECEL1|Input_PCDHGA7|Input_PCDHGC5',
#   'Input_ABCB5|Input_COL6A3|Input_DYSF',
#   'Input_BAG1|Input_PRRT2',
#   'Input_AHRR|Input_POMGNT2',
#   'Input_KIF22|Input_MYO19',
#   'Input_BAZ2A|Input_STAC3',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGA8',
#   'Input_CPT2|Input_RBM12',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGC4',
#   'Input_MYH8|Input_SCN11A|Input_SPTB',
#   'Input_COL1A1|Input_NPC1|Input_TTN',
#   'Input_SPINK5|Input_UGT1A10|Input_UGT1A3',
#   'Input_CENPT|Input_PTPRG',
#   'Input_HOXC12|Input_UGT1A3|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGC3',
#   'Input_HOXC12|Input_UGT1A1|Input_UGT1A4',
#   'Input_CNTLN|Input_FERD3L',
#   'Input_COL11A1|Input_RYR1|Input_RYR3',
#   'Input_SPIDR|Input_UGT1A4|Input_UGT1A8',
#   'Input_FBN2|Input_PCDHGA7|Input_PCDHGB5',
#   'Input_CD1C|Input_KCNH4',
#   'Input_GABRR3|Input_SPATA13',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGC4',
#   'Input_MLKL|Input_PDPR|Input_TAS1R3',
#   'Input_PLB1|Input_PSMC1',
#   'Input_CFTR|Input_MYO15A|Input_NPC1L1',
#   'Input_DTX1|Input_GLI2',
#   'Input_KRT36|Input_LGI1',
#   'Input_CAPN1|Input_CAPN3',
#   'Input_MYH7B|Input_TAS1R3|Input_TTN',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA9',
#   'Input_HMGCR|Input_UGT1A4|Input_UGT1A6',
#   'Input_PHYKPL|Input_RFC5',
#   'Input_DHRS4L2|Input_UGT1A1|Input_UGT1A4',
#   'Input_ABCA4|Input_AKT2',
#   'Input_PRAMEF8|Input_ZNF30',
#   'Input_ECEL1|Input_PCDHGA7|Input_PCDHGA8',
#   'Input_SLC4A9|Input_UGT1A1|Input_UGT1A7',
#   'Input_EXD3|Input_TCTN2',
#   'Input_LDLR|Input_MYH3|Input_MYH8',
#   'Input_SPINK5|Input_UGT1A3|Input_UGT1A5',
#   'Input_FLNB|Input_LRP6|Input_PKHD1L1',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGC3',
#   'Input_HOXC12|Input_UGT1A4|Input_UGT1A6',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGB7',
#   'Input_ACACB|Input_LDLR|Input_SEC23A',
#   'Input_SPTB|Input_TTN|Input_TYR',
#   'Input_PDHA2|Input_PIK3AP1',
#   'Input_ABCA13|Input_HELZ2|Input_TENM4',
#   'Input_HOXB1|Input_UGT1A3|Input_UGT1A8',
#   'Input_HOXB1|Input_UGT1A3|Input_UGT1A6',
#   'Input_HOXB7|Input_PCDH12',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGC3',
#   'Input_AADACL3|Input_NPC1',
#   'Input_GBA1|Input_SLC47A1',
#   'Input_ABCB4|Input_UGT1A4|Input_UGT1A8',
#   'Input_ABCB4|Input_UGT1A5|Input_UGT1A7',
#   'Input_TRPM2|Input_UMODL1',
#   'Input_SPINK5|Input_UGT1A10|Input_UGT1A8',
#   'Input_JAK3|Input_SLC15A3',
#   'Input_CFTR|Input_FBN2|Input_FLNC',
#   'Input_HOXB1|Input_UGT1A8|Input_UGT1A9',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGC5',
#   'Input_COLGALT1|Input_FZD4',
#   'Input_LTBP1|Input_RYR1|Input_TTN',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA12',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGA6',
#   'Input_ERO1B|Input_IFT140',
#   'Input_HOXC12|Input_UGT1A6',
#   'Input_FLNB|Input_LRP2|Input_MYO18A',
#   'Input_ECEL1|Input_PCDHGA9|Input_PCDHGC5',
#   'Input_BEST2|Input_TTC3',
#   'Input_ABCC1|Input_DNAH5|Input_TTN',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA3',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA6',
#   'Input_ATP7B|Input_PCDHGA2|Input_PCDHGA7',
#   'Input_HOXB1|Input_UGT1A1|Input_UGT1A4',
#   'Input_ECEL1|Input_PCDHGA8|Input_PCDHGC5',
#   'Input_PKHD1L1|Input_PLEKHB1|Input_TTN',
#   'Input_ATP7B|Input_PCDHGA2|Input_PCDHGA8',
#   'Input_CACNA1S|Input_FLNB|Input_GRM6',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGB6',
#   'Input_KAZALD1|Input_KIF27',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGB4',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGA5',
#   'Input_COL2A1|Input_MYH1|Input_TTN',
#   'Input_ADAMTS3|Input_FBXO24',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGB7',
#   'Input_ENO2|Input_SLC30A5',
#   'Input_HMX1|Input_NDUFAF5',
#   'Input_CLUH|Input_RAB27A',
#   'Input_ECEL1|Input_PCDHGA7|Input_PCDHGB4',
#   'Input_ABCB4|Input_UGT1A10|Input_UGT1A5',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGA5',
#   'Input_ATP7B|Input_PCDHGA2|Input_PCDHGA5',
#   'Input_ECEL1|Input_PCDHGB7|Input_PCDHGC4',
#   'Input_COL6A3|Input_LRP6|Input_RYR3',
#   'Input_MYO3A|Input_RXRG',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGB2',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGC5',
#   'Input_PDLIM5|Input_RIPK1',
#   'Input_CDH23|Input_GDPD1',
#   'Input_KMT2A|Input_RPP38',
#   'Input_SPIDR|Input_UGT1A10|Input_UGT1A7',
#   'Input_ATG4C|Input_SLIRP',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGC4',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGA7',
#   'Input_GUCA1A|Input_PKD2L1',
#   'Input_CRMP1|Input_MS4A14',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGB3',
#   'Input_SPINK5|Input_UGT1A6|Input_UGT1A8',
#   'Input_SPTAN1|Input_WDR70',
#   'Input_ADAP2|Input_FMNL1',
#   'Input_SPINK5|Input_UGT1A4|Input_UGT1A8',
#   'Input_ANKRD35|Input_YJU2B',
#   'Input_CMTR2|Input_FZD2',
#   'Input_SLC4A9|Input_UGT1A3|Input_UGT1A9',
#   'Input_DNAH5|Input_KRT5|Input_TTN',
#   'Input_FBN2|Input_PCDHGB1|Input_PCDHGB6',
#   'Input_HOXC12|Input_UGT1A10|Input_UGT1A8',
#   'Input_DHRS4L2|Input_UGT1A10|Input_UGT1A4',
#   'Input_DHRS4L2|Input_UGT1A3|Input_UGT1A8',
#   'Input_BYSL|Input_MYOZ1',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGC3',
#   'Input_SPIDR|Input_UGT1A4|Input_UGT1A6',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGB2',
#   'Input_HOXB1|Input_UGT1A4|Input_UGT1A7',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGA6',
#   'Input_DGCR2|Input_ZIC4',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGC4',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA8',
#   'Input_ABCA4|Input_MYH11|Input_TTN',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGA6',
#   'Input_PCDHA2|Input_RC3H2',
#   'Input_ECE1|Input_FAM181A',
#   'Input_CELSR3|Input_KRT14',
#   'Input_FBN2|Input_PCDHGA8|Input_PCDHGB1',
#   'Input_NBR1|Input_TUBA8',
#   'Input_CBY3|Input_DOCK6',
#   'Input_COL6A2|Input_GRM6|Input_TENM4',
#   'Input_SLC4A9|Input_UGT1A4|Input_UGT1A9',
#   'Input_HMGCR|Input_UGT1A6|Input_UGT1A8',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGA6',
#   'Input_GSS|Input_KCP',
#   'Input_CERCAM|Input_XRCC2',
#   'Input_HMGCR|Input_UGT1A10|Input_UGT1A4',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGC5',
#   'Input_ATP7B|Input_PCDHGA12|Input_PCDHGA3',
#   'Input_ATP7B|Input_PCDHGA10|Input_PCDHGA7',
#   'Input_BCO2|Input_TRIM3',
#   'Input_ECEL1|Input_PCDHGA9|Input_PCDHGB2',
#   'Input_KIF12|Input_VSIG10L2',
#   'Input_FBN2|Input_PCDHGC3|Input_PCDHGC4',
#   'Input_ABCB4|Input_UGT1A1|Input_UGT1A8',
#   'Input_KCNQ1|Input_RYR1|Input_TTN',
#   'Input_STARD5|Input_THBS3',
#   'Input_HMGCR|Input_UGT1A5|Input_UGT1A7',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGB7',
#   'Input_LAMB3|Input_SLC30A7',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGB2',
#   'Input_HMGCR|Input_UGT1A10|Input_UGT1A6',
#   'Input_SLC4A9|Input_UGT1A4|Input_UGT1A7',
#   'Input_ATP7B|Input_PCDHGA7|Input_PCDHGA8',
#   'Input_CROT|Input_NOD2',
#   'Input_ANXA7|Input_CCT5',
#   'Input_HMGCR|Input_UGT1A5|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGB4',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGB3',
#   'Input_LDLR|Input_SCN7A|Input_TTN',
#   'Input_FBN2|Input_PCDHGB5|Input_PCDHGB6',
#   'Input_BCHE|Input_TRPV4',
#   'Input_ALDH1L2|Input_TRAF4',
#   'Input_DYSF|Input_RYR3|Input_WFS1',
#   'Input_FICD|Input_KCNQ2',
#   'Input_ABCB4|Input_UGT1A4|Input_UGT1A6',
#   'Input_MMEL1|Input_RYR1|Input_TENM4',
#   'Input_COL11A2|Input_GLDC|Input_TTN',
#   'Input_HOXD3|Input_ZNF749',
#   'Input_C1QTNF4|Input_LY9',
#   'Input_FBN2|Input_PCDHGB1|Input_PCDHGB5',
#   'Input_ABCB4|Input_UGT1A3|Input_UGT1A7',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGA7',
#   'Input_ABCA7|Input_ACE|Input_ITPR3',
#   'Input_CLCNKA|Input_HCN3|Input_MSH2',
#   'Input_OTOF|Input_SCN11A|Input_TTN',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGC4',
#   'Input_KCNH2|Input_WDR27',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGB6',
#   'Input_DHRS4L2|Input_UGT1A6|Input_UGT1A8',
#   'Input_EIF2B2|Input_SAMD15',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGB2',
#   'Input_RB1|Input_ZCRB1',
#   'Input_CHRNA7|Input_UGT2A1|Input_UGT2A2',
#   'Input_CENPJ|Input_GPR83',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGB7',
#   'Input_ABCA7|Input_SLC26A4|Input_TTN',
#   'Input_ATP2C2|Input_FRMD4B|Input_LRP2',
#   'Input_PNPLA6|Input_TRHDE',
#   'Input_CLIC6|Input_HNRNPUL1',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGA12',
#   'Input_ECEL1|Input_PCDHGA9|Input_PCDHGB7',
#   'Input_MTFR2|Input_UBR2',
#   'Input_IGDCC3|Input_TRMT44',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGB4',
#   'Input_LY9|Input_TKFC',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGC5',
#   'Input_METTL23|Input_RARG',
#   'Input_DNAH5|Input_OBSCN|Input_RYR3',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGB6',
#   'Input_POMT1|Input_RYR1|Input_TNNI3K',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGA9',
#   'Input_DHRS4L2|Input_UGT1A4|Input_UGT1A5',
#   'Input_ADAM19|Input_MMUT',
#   'Input_LTBP4|Input_SIDT1',
#   'Input_MYL3|Input_SCAP',
#   'Input_APEH|Input_IL4I1',
#   'Input_PDCD11|Input_SLK',
#   'Input_CYP4F11|Input_LVRN',
#   'Input_DCAF6|Input_DHX33',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGB4',
#   'Input_CACNA1S|Input_MYO1C|Input_MYO7A',
#   'Input_FBN3|Input_ITPR3|Input_MYO15A',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA12',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGB1',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGB5',
#   'Input_ECEL1|Input_PCDHGB4|Input_PCDHGB5',
#   'Input_CACNA1D|Input_DPAGT1',
#   'Input_BCKDHA|Input_EARS2',
#   'Input_ABI2|Input_UPP2',
#   'Input_COL9A3|Input_IFNA5',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGA8',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGC4',
#   'Input_CENPK|Input_CP',
#   'Input_DNAH5|Input_PAH|Input_RYR3',
#   'Input_ACRBP|Input_CACNB3',
#   'Input_ECEL1|Input_PCDHGC3|Input_PCDHGC5',
#   'Input_LRP6|Input_RYR3|Input_SMPD1',
#   'Input_HOXB1|Input_UGT1A10|Input_UGT1A4',
#   'Input_CLSTN1|Input_PNPLA4',
#   'Input_DHRS4L2|Input_UGT1A3|Input_UGT1A4',
#   'Input_CEP295|Input_HSPG2',
#   'Input_FERD3L|Input_KIDINS220',
#   'Input_ERCC2|Input_PARN',
#   'Input_HMGCR|Input_UGT1A7|Input_UGT1A8',
#   'Input_IFIT2|Input_POLH',
#   'Input_VARS2|Input_YY1AP1',
#   'Input_SLC4A9|Input_UGT1A10|Input_UGT1A6',
#   'Input_DDX55|Input_ITPR3|Input_TTN',
#   'Input_GNAO1|Input_UNC13D',
#   'Input_ECEL1|Input_ZNF17',
#   'Input_PTTG1IP|Input_USP45',
#   'Input_ALPL|Input_ATP7B|Input_TTC28',
#   'Input_FBN2|Input_PCDHGB4|Input_PCDHGC4',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGA5',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGB4',
#   'Input_CYP4B1|Input_SETD7',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGA4',
#   'Input_ABCA13|Input_FANCA|Input_FBN3',
#   'Input_HMGCR|Input_UGT1A4|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA11',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGA7',
#   'Input_APLP2|Input_DOCK1',
#   'Input_GLRA2|Input_LMF1',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGB1',
#   'Input_CACNA1S|Input_GAA|Input_TTN',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGC5',
#   'Input_PRIMPOL|Input_SERPINA7',
#   'Input_DHRS4L2|Input_UGT1A10|Input_UGT1A5',
#   'Input_ECEL1|Input_PCDHGB3|Input_PCDHGC4',
#   'Input_COL5A2|Input_HELZ',
#   'Input_DHRS4L2|Input_UGT1A10|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGC4',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGB5',
#   'Input_GDF15|Input_TGFBI',
#   'Input_ALDH18A1|Input_NFS1',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGC5',
#   'Input_CACNA1H|Input_CFTR|Input_SLC12A4',
#   'Input_HOXC12|Input_UGT1A3|Input_UGT1A5',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGB7',
#   'Input_HOXB1|Input_UGT1A4|Input_UGT1A5',
#   'Input_HOXC13|Input_SLCO1B3',
#   'Input_FBN2|Input_PCDHGB4|Input_PCDHGC5',
#   'Input_FLNB|Input_LRP1B|Input_LRP2',
#   'Input_FBN2|Input_PCDHGB5|Input_PCDHGC5',
#   'Input_C3AR1|Input_SLC2A9',
#   'Input_FBN2|Input_PCDHGB6|Input_PCDHGC3',
#   'Input_CLEC11A|Input_SPTLC1',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGC5',
#   'Input_KIAA0319|Input_SDHA',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGB3',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGB3',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGC3',
#   'Input_FBN2|Input_PCDHGA7|Input_PCDHGB2',
#   'Input_CYB5D2|Input_TNR',
#   'Input_SPINK5|Input_UGT1A4|Input_UGT1A7',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA10',
#   'Input_KLKB1|Input_METTL23',
#   'Input_IHH|Input_UNC13B',
#   'Input_CYP24A1|Input_OTP',
#   'Input_ATP7B|Input_PCDHGA8|Input_PCDHGB3',
#   'Input_ABCA7|Input_FLNB|Input_MYH8',
#   'Input_FBN2|Input_PCDHGA9|Input_PCDHGB2',
#   'Input_FBN2|Input_PCDHGB1|Input_PCDHGC3',
#   'Input_HOXC12|Input_UGT1A5|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGB7',
#   'Input_ABCC9|Input_BRF1',
#   'Input_IL18RAP|Input_SULT1A1',
#   'Input_RABL6|Input_STIP1',
#   'Input_RLN3|Input_SLC20A2',
#   'Input_DDX60L|Input_UGT2A1|Input_UGT2A2',
#   'Input_RYR2|Input_TENM4|Input_TTN',
#   'Input_TULP4|Input_YIF1A',
#   'Input_OR6A2|Input_RIMS1',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGA9',
#   'Input_MYO15A|Input_WNT11',
#   'Input_SPIDR|Input_UGT1A8',
#   'Input_FNDC4|Input_OR2H1',
#   'Input_ATP7B|Input_PCDHGA10|Input_PCDHGA2',
#   'Input_HOXC12|Input_UGT1A5|Input_UGT1A6',
#   'Input_COL6A2|Input_COLQ|Input_TTN',
#   'Input_ATP7B|Input_PCDHGA5|Input_PCDHGB7',
#   'Input_ATP7B|Input_MAGEL2',
#   'Input_ATP7B|Input_PCDHGA1|Input_PCDHGA5',
#   'Input_SLC4A9|Input_UGT1A10|Input_UGT1A5',
#   'Input_DNAH3|Input_RYR1|Input_VWDE',
#   'Input_FBN2|Input_PCDHGB4|Input_PCDHGB6',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGA7',
#   'Input_ABCA7|Input_COL6A3|Input_MYH8',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGB1',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGB3',
#   'Input_GTF2I|Input_LRP1',
#   'Input_BTAF1|Input_CENPQ',
#   'Input_MYO1E|Input_PIK3CG',
#   'Input_ATP7B|Input_PCDHGA10|Input_PCDHGB4',
#   'Input_DDR1|Input_ZNF433',
#   'Input_CACNA2D4|Input_FAM98C',
#   'Input_DHRS4L2|Input_UGT1A4|Input_UGT1A7',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGB7',
#   'Input_ANK2|Input_FTCD',
#   'Input_ABCA4|Input_CFTR|Input_MYH7B',
#   'Input_SLC4A9|Input_UGT1A1|Input_UGT1A10',
#   'Input_FBN3|Input_RYR3|Input_TENM2',
#   'Input_LNX1|Input_SLC22A13',
#   'Input_GLDN|Input_SLC17A2',
#   'Input_AP3M2|Input_DNAH5|Input_MYH3',
#   'Input_CFTR|Input_DHTKD1|Input_RYR1',
#   'Input_LMF2|Input_OR52M1',
#   'Input_MYO5C|Input_OR8B8',
#   'Input_FBP1|Input_STXBP2',
#   'Input_ABCC1|Input_FLNB|Input_TTN',
#   'Input_CYP2D6|Input_GAS8',
#   'Input_ACACB|Input_THBS4|Input_TRPM1',
#   'Input_MYO15A|Input_PAH|Input_PYGB',
#   'Input_DNAH9|Input_TNS1|Input_TTN',
#   'Input_PDE4D|Input_PRKCQ',
#   'Input_DNAH10|Input_EP400',
#   'Input_JHY|Input_NLRP12',
#   'Input_LGI3|Input_SLC39A14',
#   'Input_ACAD10|Input_FGFRL1',
#   'Input_ACY1|Input_PKHD1L1|Input_SEMA3B',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGB1',
#   'Input_FBN2|Input_PCDHGC3|Input_PCDHGC5',
#   'Input_ABCC2|Input_TTN|Input_VSX1',
#   'Input_CACNA1H|Input_CFTR|Input_HELZ',
#   'Input_ARHGAP11A|Input_PGA5',
#   'Input_ITGA1|Input_TOP3B',
#   'Input_GRM3|Input_PLS1',
#   'Input_HMGCR|Input_UGT1A5|Input_UGT1A9',
#   'Input_DMD|Input_DSP',
#   'Input_ANO4|Input_UNC13D',
#   'Input_SPINK5|Input_UGT1A1|Input_UGT1A10',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGC5',
#   'Input_COL17A1|Input_SCN9A|Input_SLC45A4',
#   'Input_HOXB1|Input_UGT1A10|Input_UGT1A3',
#   'Input_CSH2|Input_UGT2A1|Input_UGT2A2',
#   'Input_DRGX|Input_KIF3B',
#   'Input_ECEL1|Input_PCDHGB3|Input_PCDHGC5',
#   'Input_PAX1|Input_WWP2',
#   'Input_HMGCR|Input_UGT1A8|Input_UGT1A9',
#   'Input_KIAA2012|Input_SCRT2',
#   'Input_ABCC6|Input_PRDX3',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGC5',
#   'Input_FBN2|Input_PCDHGB6|Input_PCDHGB7',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGA7',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGA7',
#   'Input_ATP7B|Input_PCDHGA3|Input_PCDHGB1',
#   'Input_FBN2|Input_PCDHGA6|Input_PCDHGB6',
#   'Input_BEST3|Input_LRRK2',
#   'Input_AGMAT|Input_APPL1',
#   'Input_ABCA4|Input_ATP7B|Input_SYNE1',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGA12',
#   'Input_HOXB1|Input_UGT1A1|Input_UGT1A10',
#   'Input_ECEL1|Input_PCDHGB6|Input_PCDHGC4',
#   'Input_SLC4A9|Input_UGT1A10|Input_UGT1A8',
#   'Input_POTEJ|Input_PRPF38A',
#   'Input_SERPINI1|Input_SLC12A6',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGC4',
#   'Input_TRIM2|Input_VNN2',
#   'Input_PBX3|Input_SH2D3A',
#   'Input_HOXC12|Input_UGT1A4|Input_UGT1A9',
#   'Input_PKHD1L1|Input_POLQ|Input_TTN',
#   'Input_DIS3|Input_PRX',
#   'Input_ATM|Input_MALRD1',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGB5',
#   'Input_HOXC12|Input_UGT1A7|Input_UGT1A8',
#   'Input_SPIDR|Input_UGT1A3|Input_UGT1A9',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGA5',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A7',
#   'Input_FAT1|Input_OBSCN|Input_TENM4',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGC4',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGA3',
#   'Input_CFTR|Input_RYR1|Input_TRNT1',
#   'Input_CFTR|Input_ERBB3|Input_MYH1',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGB6',
#   'Input_COL6A3|Input_MYH8|Input_SACS',
#   'Input_PDK2|Input_WNT8A',
#   'Input_ASZ1|Input_OPLAH',
#   'Input_CYSLTR2|Input_RNASEH2B',
#   'Input_DNAH1|Input_H6PD|Input_RYR3',
#   'Input_LRP2|Input_STAB1|Input_VWA2',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGA8',
#   'Input_CTSC|Input_PON1',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGA7',
#   'Input_CFAP206|Input_DPH1',
#   'Input_ABCC3|Input_CFTR|Input_KIF26B',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA12',
#   'Input_CAD|Input_CFTR|Input_CTC1',
#   'Input_HOXC12|Input_UGT1A3|Input_UGT1A9',
#   'Input_ABCC2|Input_MYO7A|Input_PAH',
#   'Input_KLC1|Input_PRSS53',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGA9',
#   'Input_ACACA|Input_C1QTNF7',
#   'Input_ITPR1|Input_TMEM191B|Input_TMEM191C',
#   'Input_POLH|Input_UGT2A1|Input_UGT2A2',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGC4',
#   'Input_NMRK2|Input_RARB',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGA9',
#   'Input_FGG|Input_TRIM5',
#   'Input_FGR|Input_GABRE',
#   'Input_FBN3|Input_MCCC2|Input_NPHP4',
#   'Input_MYH14|Input_THBS2|Input_TTN',
#   'Input_MICALL2|Input_TRIM60',
#   'Input_ABCC10|Input_COL5A3|Input_SLC22A7',
#   'Input_AZIN2|Input_BBS4',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGB1',
#   'Input_KIF26A|Input_OBSCN|Input_RYR1',
#   'Input_HOXC12|Input_UGT1A1|Input_UGT1A5',
#   'Input_ITPR3|Input_THAP10',
#   'Input_CD36|Input_TDRD12',
#   'Input_ANKK1|Input_DNAH3|Input_RYR3',
#   'Input_HHATL|Input_MYO1A|Input_WDR48',
#   'Input_ECEL1|Input_PCDHGA7|Input_PCDHGB1',
#   'Input_PKHD1L1|Input_SLAMF8',
#   'Input_CLTCL1|Input_STARD8',
#   'Input_DDIAS|Input_JAK2',
#   'Input_SLC45A1|Input_ZNF607',
#   'Input_FBN2|Input_PCDHGB2|Input_PCDHGC5',
#   'Input_CACNA1H|Input_PLEC|Input_WFS1',
#   'Input_ABCB4|Input_UGT1A10|Input_UGT1A8',
#   'Input_HOXC12|Input_UGT1A6|Input_UGT1A9',
#   'Input_FBN3|Input_SMO|Input_TTN',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A8',
#   'Input_ATP12A|Input_POLD2',
#   'Input_FBN2|Input_PCDHGA7|Input_PCDHGB6',
#   'Input_OPRL1|Input_VKORC1',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGC3',
#   'Input_DHRS4L2|Input_UGT1A8|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGA8|Input_PCDHGB5',
#   'Input_DNAH5|Input_MYO18B|Input_RYR1',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGA8',
#   'Input_CROT|Input_FLNC|Input_TENM4',
#   'Input_SPIDR|Input_UGT1A10|Input_UGT1A3',
#   'Input_ECEL1|Input_PCDHGB4|Input_PCDHGB7',
#   'Input_ABCA4|Input_MYO7A|Input_MYO7B',
#   'Input_FBN2|Input_PCDHGA8|Input_PCDHGC4',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGB5',
#   'Input_EFTUD2|Input_KIF21B',
#   'Input_LDLR|Input_SCN9A|Input_TTN',
#   'Input_PKHD1L1|Input_TIPARP',
#   'Input_FCRL6|Input_INSRR',
#   'Input_GARNL3|Input_SLC2A8',
#   'Input_ITPR3|Input_SCN10A|Input_TTN',
#   'Input_BMPR1B|Input_SHC2',
#   'Input_KIF4B|Input_RGS21',
#   'Input_HSP90B1|Input_NF1',
#   'Input_BBS9|Input_C1orf53',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA7',
#   'Input_DTX2|Input_SLC25A45',
#   'Input_C9orf131|Input_PCDH12',
#   'Input_CFTR|Input_PYGM|Input_SULF2',
#   'Input_MYH4|Input_SPTB|Input_TTN',
#   'Input_F5|Input_RYR3|Input_SACS',
#   'Input_DST|Input_RYR3|Input_SCN9A',
#   'Input_ECEL1|Input_PCDHGA9|Input_PCDHGC3',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGB2',
#   'Input_BIRC6|Input_MAP4',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGA7',
#   'Input_ECEL1|Input_PCDHGB2|Input_PCDHGC5',
#   'Input_SPIDR|Input_UGT1A5|Input_UGT1A6',
#   'Input_POP1|Input_SLC4A11',
#   'Input_ACE|Input_DNAH5|Input_FLNB',
#   'Input_GCAT|Input_PLEKHM3',
#   'Input_SEMA7A|Input_SLC35C2',
#   'Input_AGPAT3|Input_ENTPD4',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGB7',
#   'Input_NLRP6|Input_TGOLN2',
#   'Input_SPINK5|Input_UGT1A6|Input_UGT1A9',
#   'Input_CAPN3|Input_COL5A1|Input_NAV2',
#   'Input_HOXC12|Input_UGT1A1|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGC4',
#   'Input_LMAN1|Input_TUBD1',
#   'Input_DNAH3|Input_MYH1|Input_MYO7A',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGB4',
#   'Input_CFTR|Input_MAN2B2|Input_MYH8',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGA2',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGB4',
#   'Input_FBN2|Input_PCDHGA1|Input_PCDHGB6',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A9',
#   'Input_CLDN16|Input_MTMR14',
#   'Input_GSE1|Input_PSPN',
#   'Input_LRRC8E|Input_UGT2A1|Input_UGT2A2',
#   'Input_ECEL1|Input_PCDHGB4|Input_PCDHGC5',
#   'Input_MYH9|Input_SLC25A13',
#   'Input_HMOX2|Input_TGFBR2',
#   'Input_SLC4A9|Input_UGT1A6|Input_UGT1A9',
#   'Input_ATP4A|Input_ZNF793',
#   'Input_FBN2|Input_PCDHGA11|Input_PCDHGA4',
#   'Input_HMGCR|Input_UGT1A10|Input_UGT1A8',
#   'Input_DHRS4L2|Input_FAAH2',
#   'Input_SPINK5|Input_UGT1A6|Input_UGT1A7',
#   'Input_FBN2|Input_PCDHGB4|Input_PCDHGB5',
#   'Input_ANK2|Input_CACNA1H|Input_TTN',
#   'Input_HOXC12|Input_UGT1A1',
#   'Input_FBN2|Input_PCDHGB2|Input_PCDHGB3',
#   'Input_ECEL1|Input_PCDHGA12|Input_PCDHGC3',
#   'Input_MYH14|Input_NR1D1',
#   'Input_STARD5|Input_SYNGR1',
#   'Input_DNAH14|Input_MYH4|Input_TENM4',
#   'Input_HOXB1|Input_UGT1A5|Input_UGT1A9',
#   'Input_NAT9|Input_VDR',
#   'Input_DNAH6|Input_SLC36A2',
#   'Input_SPIDR|Input_UGT1A8|Input_UGT1A9',
#   'Input_FBN2|Input_PCDHGA5|Input_PCDHGA7',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGB3',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGC3',
#   'Input_ATG2A|Input_ZNF268',
#   'Input_BMS1|Input_SPR',
#   'Input_ABCA7|Input_SLC7A9|Input_TTN',
#   'Input_CDHR5|Input_LGALS3',
#   'Input_ATP7B|Input_LRP1|Input_RP1L1',
#   'Input_FBN2|Input_PCDHGB1|Input_PCDHGC5',
#   'Input_MED15|Input_WNT2B',
#   'Input_FBN2|Input_PCDHGB2|Input_PCDHGC3',
#   'Input_ECEL1|Input_PCDHGA10|Input_PCDHGC3',
#   'Input_GPR33|Input_LRP4',
#   'Input_ECEL1|Input_PCDHGA3|Input_PCDHGB5',
#   'Input_HOXC12|Input_UGT1A1|Input_UGT1A10',
#   'Input_SPINK5|Input_UGT1A3|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGA2|Input_PCDHGB4',
#   'Input_SETD1B|Input_SH3BGR',
#   'Input_AMY2A|Input_ANGEL1',
#   'Input_DNAH3|Input_RSPO4|Input_TTN',
#   'Input_FBN2|Input_PCDHGA8|Input_PCDHGB2',
#   'Input_DBX1|Input_EEF2K',
#   'Input_AMZ2|Input_GFUS',
#   'Input_ECEL1|Input_PCDHGB5|Input_PCDHGB6',
#   'Input_FBN2|Input_PCDHGA10|Input_PCDHGA5',
#   'Input_SLC4A9|Input_UGT1A3|Input_UGT1A4',
#   'Input_ECEL1|Input_PCDHGB1|Input_PCDHGB3',
#   'Input_FBN2|Input_PCDHGA4|Input_PCDHGB5',
#   'Input_FBN2|Input_PCDHGA12|Input_PCDHGA4',
#   'Input_MBD2|Input_SCN5A',
#   'Input_PKD2L2|Input_SHH',
#   'Input_SLC4A9|Input_UGT1A8|Input_UGT1A9',
#   'Input_ECEL1|Input_PCDHGA5|Input_PCDHGA9',
#   'Input_COLEC10|Input_MFSD13A',
#   'Input_BPIFA2|Input_PLCG1',
#   'Input_CACNA1S|Input_COL4A4|Input_OBSCN',
#   'Input_SPINK5|Input_UGT1A3|Input_UGT1A7',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGB4',
#   'Input_ECEL1|Input_PCDHGA9|Input_PCDHGB1',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGA7',
#   'Input_DHRS4L2|Input_UGT1A4|Input_UGT1A6',
#   'Input_SPIDR|Input_UGT1A5|Input_UGT1A9',
#   'Input_CFTR|Input_DNAH5|Input_RYR3',
#   'Input_HMGCR|Input_UGT1A3|Input_UGT1A9',
#   'Input_ABCB4|Input_UGT1A5|Input_UGT1A9',
#   'Input_ILDR1|Input_UGT2A1|Input_UGT2A2',
#   'Input_CACNA1S|Input_OBSCN|Input_PAH',
#   'Input_SPINK5|Input_UGT1A10|Input_UGT1A6',
#   'Input_APOLD1|Input_MYH10',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA3',
#   'Input_ALOX15B|Input_MYH1|Input_MYH7B',
#   'Input_MYL10|Input_SAMD3',
#   'Input_KRT6A|Input_TENM4|Input_TTN',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGB3',
#   'Input_DGAT1|Input_PGAM2',
#   'Input_ABCB4|Input_UGT1A10|Input_UGT1A4',
#   'Input_FBN2|Input_PCDHGA2|Input_PCDHGA4',
#   'Input_CHD7|Input_LILRB1',
#   'Input_FBN2|Input_PCDHGA3|Input_PCDHGB1',
#   'Input_ABCC3|Input_MYO1C|Input_SH3TC1',
#   'Input_SPIDR|Input_UGT1A1|Input_UGT1A6',
#   'Input_FBN2|Input_PCDHGA8|Input_PCDHGB7',
#   'Input_FBN2|Input_PCDHGA7|Input_PCDHGB1',
#   'Input_ARHGEF25|Input_B4GALNT1',
#   'Input_ABCA3|Input_AFDN|Input_TENM4',
#   'Input_BLM|Input_MESP2',
#   'Input_ESRRG|Input_SPATA31C1',
#   'Input_LRP1B|Input_MYO15A|Input_TENM2',
#   'Input_SLC4A9|Input_UGT1A1|Input_UGT1A5',
#   'Input_SPIDR|Input_UGT1A3|Input_UGT1A4',
#   'Input_SLC12A1|Input_TMEM185A',
#   'Input_ECEL1|Input_PCDHGA4|Input_PCDHGB4',
#   'Input_CACNA1H|Input_HEPHL1|Input_PKHD1L1',
#   'Input_ECEL1|Input_PCDHGA6|Input_PCDHGB7',
#   'Input_AVL9|Input_MMEL1',
#   'Input_ABCB4|Input_UGT1A10|Input_UGT1A3',
#   'Input_KRT27|Input_LCTL',
#   'Input_ABCC5|Input_FBN3|Input_FLNB',
#   'Input_AMPD1|Input_RYR3|Input_TTN',
#   'Input_MYO7B|Input_SACS|Input_TTN',
#   'Input_ATP2A3|Input_TAAR9',
#   'Input_ABCA4|Input_AKT2|Input_FBN2',
#   'Input_ECEL1|Input_PCDHGA1|Input_PCDHGA6',
#   'Input_ECEL1|Input_PCDHGB6|Input_PCDHGC5',
#   'Input_FBN2|Input_PCDHGB3|Input_PCDHGB7',
#   'Input_SPINK5|Input_UGT1A8|Input_UGT1A9',
#   'Input_SLC4A9|Input_UGT1A5|Input_UGT1A9',
#   'Input_HMGCR|Input_UGT1A3|Input_UGT1A7',
#   'Input_ELOVL7|Input_TRIM4',
#   ...},
#  (('british_male',),
#   ('british',
#    'british_female',
#    'pre_menopause',
#    'post_menopause')): {'Input_AAAS|Input_PARVA',
#   'Input_ABCA10|Input_PEX6',
#   'Input_ABCA12|Input_DOCK5',
#   'Input_ABCA13|Input_PMP22',
#   'Input_ABCA13|Input_SHD',
#   'Input_ABCA1|Input_DGKD',
#   'Input_ABCA1|Input_ZNF177',
#   'Input_ABCA3|Input_PARP2',
#   'Input_ABCA4|Input_PDE4A',
#   'Input_ABCA5|Input_ANKS6',
#   'Input_ABCA7|Input_HAVCR1',
#   'Input_ABCA7|Input_NTN3',
#   'Input_ABCA7|Input_OTOF|Input_STAB2',
#   'Input_ABCA9|Input_ALDH1B1',
#   'Input_ABCA9|Input_CD207',
#   'Input_ABCB10|Input_ENPP3',
#   'Input_ABCB10|Input_ZNF607',
#   'Input_ABCB9|Input_PKD1L3',
#   'Input_ABCB9|Input_SOX13',
#   'Input_ABCC10|Input_NCOR1',
#   'Input_ABCC11|Input_FBXO7',
#   'Input_ABCC11|Input_PLCD1',
#   'Input_ABCC11|Input_PROM1',
#   'Input_ABCC1|Input_SETBP1',
#   'Input_ABCC1|Input_TUBA8',
#   'Input_ABCC2|Input_COX4I2',
#   'Input_ABCC2|Input_FBN3|Input_TTN',
#   'Input_ABCC3|Input_ST18',
#   'Input_ABCC5|Input_PLAT',
#   'Input_ABCC5|Input_ZMIZ1',
#   'Input_ABCD1|Input_PLCD1',
#   'Input_ABCF2|Input_DHRS4L2',
#   'Input_ABCF3|Input_RPL36AL',
#   'Input_ABCG2|Input_SIGLEC1',
#   'Input_ABCG8|Input_ALDH8A1',
#   'Input_ABHD18|Input_BRCA1',
#   'Input_ABI2|Input_MAP3K9',
#   'Input_ABLIM2|Input_PLEKHH2',
#   'Input_ACAA1|Input_ZFP62',
#   'Input_ACAD10|Input_DNAH5|Input_TENM4',
#   'Input_ACAD9|Input_AHRR',
#   'Input_ACAD9|Input_SEC24C',
#   'Input_ACADM|Input_NOS1',
#   'Input_ACE|Input_CRB1',
#   'Input_ACO2|Input_B3GNT5',
#   'Input_ACO2|Input_SMARCAL1',
#   'Input_ACOX3|Input_ATP2B2',
#   'Input_ACOX3|Input_CREBBP',
#   'Input_ACSM2A|Input_HMMR',
#   'Input_ACSM2B|Input_IARS1',
#   'Input_ACSM2B|Input_NOTCH1',
#   'Input_ACTL6A|Input_SMAD9',
#   'Input_ACTN1|Input_NELL1',
#   'Input_ACTN2|Input_KLC3',
#   'Input_ACTR10|Input_KCNQ3',
#   'Input_ACTR5|Input_BRCA1',
#   'Input_ACTRT2|Input_IQGAP3',
#   'Input_ACTRT2|Input_RECQL',
#   'Input_ADAM18|Input_TMPRSS12',
#   'Input_ADAM32|Input_COX5A',
#   'Input_ADAM8|Input_PNPLA6',
#   'Input_ADAMTS10|Input_POMT1',
#   'Input_ADAMTS2|Input_IRF3',
#   'Input_ADAMTS8|Input_CASQ1',
#   'Input_ADAMTS8|Input_PTGIR',
#   'Input_ADAMTSL3|Input_CCNO',
#   'Input_ADAMTSL3|Input_REXO5',
#   'Input_ADARB2|Input_MOK',
#   'Input_ADAT1|Input_DOK4',
#   'Input_ADA|Input_CYP7B1',
#   'Input_ADA|Input_FRAS1',
#   'Input_ADA|Input_SLC5A10',
#   'Input_ADCK1|Input_SLC22A16',
#   'Input_ADCY4|Input_HLA-C',
#   'Input_ADCY6|Input_LMAN1',
#   'Input_ADCY6|Input_NDUFA8',
#   'Input_ADCY7|Input_SAMD3',
#   'Input_ADGRA3|Input_NIPBL',
#   'Input_ADGRF4|Input_SLC45A2',
#   'Input_ADGRL1|Input_ZNF90',
#   'Input_ADORA2B|Input_DHRS9',
#   'Input_AFG1L|Input_SLC22A16',
#   'Input_AGAP1|Input_CAPN10',
#   'Input_AGA|Input_ASPA',
#   'Input_AGA|Input_FAM200A',
#   'Input_AGMAT|Input_MCPH1',
#   'Input_AGRN|Input_PLEKHF1',
#   'Input_AGXT|Input_ZNF528',
#   'Input_AHNAK2|Input_KCNS3',
#   'Input_AK2|Input_ARSA',
#   'Input_AKR1B1|Input_SLC26A4',
#   'Input_AKR1C3|Input_HP',
#   'Input_AKR7A2|Input_LRP4',
#   'Input_ALAD|Input_PGAM2',
#   'Input_ALAS1|Input_H4C2',
#   'Input_ALB|Input_CES5A',
#   'Input_ALDH1B1|Input_HABP2',
#   'Input_ALDH1L2|Input_ATP6V1C2',
#   'Input_ALDH4A1|Input_NOX4',
#   'Input_ALDOB|Input_AMZ1',
#   'Input_ALG10B|Input_INO80',
#   'Input_ALG14|Input_INTS1',
#   'Input_ALOX12B|Input_NME8',
#   'Input_ALOX15B|Input_SELENBP1',
#   'Input_ALOXE3|Input_DPYS',
#   'Input_ALPI|Input_PPP5C',
#   'Input_ALPI|Input_TGFBR2',
#   'Input_ALPK3|Input_TLL2',
#   'Input_ALPL|Input_PARP15',
#   'Input_ALPP|Input_ANGPTL7',
#   'Input_ALPP|Input_FIP1L1',
#   'Input_ALS2|Input_KLC4',
#   'Input_ALS2|Input_LRP3',
#   'Input_ALX4|Input_CHD6',
#   'Input_AMBRA1|Input_TRPV3',
#   'Input_AMN|Input_MLH1',
#   'Input_AMPD3|Input_TRIM6',
#   'Input_AMY2B|Input_VPS13B',
#   'Input_ANGEL1|Input_MYH10',
#   'Input_ANGPTL7|Input_GRHPR',
#   'Input_ANKRD11|Input_RYR1',
#   'Input_ANKRD30A|Input_SLC12A8',
#   'Input_ANKRD6|Input_TIE1',
#   'Input_ANO2|Input_GPR176',
#   'Input_ANO5|Input_AQR',
#   'Input_ANO6|Input_DNAH5',
#   'Input_ANXA6|Input_MTHFR',
#   'Input_ANXA6|Input_SLC5A9',
#   'Input_AOC2|Input_CREB3',
#   'Input_APC|Input_MTTP',
#   'Input_APOB|Input_CAPN15',
#   'Input_APOL5|Input_FBN3',
#   'Input_AQR|Input_KIF21A',
#   'Input_ARHGAP11A|Input_PPEF2',
#   'Input_ARHGAP22|Input_FARP1',
#   'Input_ARHGEF18|Input_CAPN10',
#   'Input_ARHGEF18|Input_PCK2',
#   'Input_ARHGEF28|Input_PYGB',
#   'Input_ARHGEF38|Input_CREB3',
#   'Input_ARHGEF38|Input_SLC6A13',
#   'Input_ARL14|Input_WDR49',
#   'Input_ARMH4|Input_COL2A1',
#   'Input_ARRDC2|Input_RYR2',
#   'Input_ARSA|Input_BIRC6',
#   'Input_ARSJ|Input_NIPSNAP2',
#   'Input_ASH1L|Input_RXFP1',
#   'Input_ASXL1|Input_PDE11A',
#   'Input_ATAD3A|Input_C2',
#   'Input_ATG16L2|Input_COL1A1',
#   'Input_ATG2A|Input_DNAH5',
#   'Input_ATG7|Input_MED15',
#   'Input_ATM|Input_RIMS1',
#   'Input_ATM|Input_SLC4A1',
#   'Input_ATP10A|Input_SOX9',
#   'Input_ATP10D|Input_NUBP1',
#   'Input_ATP11B|Input_MYH4',
#   'Input_ATP12A|Input_PDLIM3',
#   'Input_ATP1A1|Input_CPT2',
#   'Input_ATP1A4|Input_GAD2',
#   'Input_ATP2A3|Input_PTPN23',
#   'Input_ATP2B1|Input_PRPH',
#   'Input_ATP2B4|Input_COL28A1',
#   'Input_ATP2C2|Input_CRAMP1',
#   'Input_ATP4A|Input_BFSP1',
#   'Input_ATP4A|Input_CPT2',
#   'Input_ATP6V0A2|Input_PIEZO2',
#   'Input_ATP6V1A|Input_SSC5D',
#   'Input_ATP7B|Input_OTOF|Input_TTN',
#   'Input_ATP7B|Input_SCN5A|Input_TTN',
#   'Input_ATP8B3|Input_SDR9C7',
#   'Input_ATR|Input_SLC2A14',
#   'Input_ATR|Input_SLFN12',
#   'Input_AURKC|Input_CSMD2',
#   'Input_BAIAP2L1|Input_RYR3',
#   'Input_BARHL2|Input_GUCY2D',
#   'Input_BBS1|Input_HEG1',
#   'Input_BBS2|Input_CACNA1B',
#   'Input_BBS2|Input_PGM5',
#   'Input_BBS2|Input_SERPINA12',
#   'Input_BBS4|Input_KCNJ16',
#   'Input_BBS7|Input_MEAK7',
#   'Input_BBX|Input_SLC6A9',
#   'Input_BBX|Input_TDRD9',
#   'Input_BCAR3|Input_TRIM59',
#   'Input_BCAT2|Input_ENO3',
#   'Input_BCKDHA|Input_SIMC1',
#   'Input_BCKDHB|Input_EIF2B5',
#   'Input_BCO1|Input_ENG',
#   'Input_BCR|Input_LPO',
#   'Input_BCS1L|Input_FRAS1',
#   'Input_BDNF|Input_SERPIND1',
#   'Input_BDNF|Input_WNT9B',
#   'Input_BEST1|Input_LTBP2',
#   'Input_BEST4|Input_SPTB',
#   'Input_BET1|Input_DNAH3',
#   'Input_BIRC6|Input_LIMS1',
#   'Input_BOLA1|Input_TPCN2',
#   'Input_BRCA1|Input_UCP2',
#   'Input_BRCA2|Input_DECR1',
#   'Input_BSN|Input_VIM',
#   'Input_BTN3A3|Input_COL6A3',
#   'Input_C17orf99|Input_MYH13',
#   'Input_C19orf44|Input_DGKH',
#   'Input_C19orf44|Input_KLHL1',
#   'Input_C19orf67|Input_MYH15',
#   'Input_C1QC|Input_KIF26A',
#   'Input_C22orf23|Input_XPNPEP3',
#   'Input_C4orf51|Input_GFPT2',
#   'Input_C6|Input_PCK2',
#   'Input_C8A|Input_ZCCHC4',
#   'Input_C8G|Input_CEP290',
#   'Input_CACFD1|Input_SH2B3',
#   'Input_CACNA1A|Input_MYH3',
#   'Input_CACNA1B|Input_RGS9BP',
#   'Input_CACNA1D|Input_HADH',
#   'Input_CACNA1D|Input_NR4A2',
#   'Input_CACNA1D|Input_TLX1',
#   'Input_CACNA1F|Input_PPHLN1',
#   'Input_CACNA1H|Input_SLC37A1',
#   'Input_CACNA1I|Input_LPA',
#   'Input_CACNA1S|Input_CAPN13',
#   'Input_CACNA1S|Input_LRP6',
#   'Input_CACNA1S|Input_SNX15',
#   'Input_CADPS2|Input_GATA6',
#   'Input_CADPS2|Input_NECTIN2',
#   'Input_CADPS|Input_CAPN2',
#   'Input_CAD|Input_GALM',
#   'Input_CALCR|Input_SLC25A26',
#   'Input_CAND2|Input_NIPSNAP3A',
#   'Input_CAPN10|Input_PNPLA2',
#   'Input_CAPN14|Input_MTMR11',
#   'Input_CAPN14|Input_SLC15A1',
#   'Input_CAPN5|Input_TRIM65',
#   'Input_CAPN8|Input_CASZ1',
#   'Input_CARD6|Input_TUBA8',
#   'Input_CARNS1|Input_PTPN3',
#   'Input_CARS2|Input_CLN8',
#   'Input_CASP10|Input_FTO',
#   'Input_CASR|Input_SMARCA1',
#   'Input_CATSPER4|Input_TPSAB1',
#   'Input_CCDC168|Input_CRELD1',
#   'Input_CCDC183|Input_MYO18A',
#   'Input_CCDC66|Input_CLIC6',
#   'Input_CCDC66|Input_ZMYND10',
#   'Input_CCDC66|Input_ZNF334',
#   'Input_CCR2|Input_CHD1L',
#   'Input_CCT5|Input_PDE6A',
#   'Input_CCZ1|Input_ITIH1',
#   'Input_CD109|Input_GFUS',
#   'Input_CDAN1|Input_CRX',
#   'Input_CDAN1|Input_RPUSD2',
#   'Input_CDH23|Input_DMBT1',
#   'Input_CDH23|Input_PYGB',
#   'Input_CDH24|Input_PKDREJ',
#   'Input_CDH24|Input_TG',
#   'Input_CDH26|Input_HNF4A',
#   'Input_CDH3|Input_THBS3',
#   'Input_CDH4|Input_PCSK4',
#   'Input_CDHR3|Input_NES',
#   'Input_CDIP1|Input_SPTBN5',
#   'Input_CDK15|Input_GATA5',
#   'Input_CELA2B|Input_NPR1',
#   'Input_CELSR1|Input_FAHD1',
#   'Input_CELSR3|Input_NIN',
#   'Input_CEMIP2|Input_GPLD1',
#   'Input_CEMIP2|Input_HAGH',
#   'Input_CENPJ|Input_OR5H6',
#   'Input_CENPN|Input_SLC6A13',
#   'Input_CENPT|Input_HAL',
#   'Input_CEP104|Input_KCNC4',
#   'Input_CEP162|Input_PYGB',
#   'Input_CEP164|Input_TTN',
#   'Input_CEP290|Input_OR52B2',
#   'Input_CERS4|Input_SGCE',
#   'Input_CES3|Input_GJA4',
#   'Input_CFAP210|Input_FBN3',
#   'Input_CFAP210|Input_SCN7A',
#   'Input_CFAP43|Input_LRP6',
#   'Input_CFI|Input_MCOLN3',
#   'Input_CFTR|Input_EFCAB14',
#   'Input_CFTR|Input_PAX4',
#   'Input_CGREF1|Input_TMPRSS15',
#   'Input_CHD1L|Input_NAGA',
#   'Input_CHD2|Input_UPK3A',
#   'Input_CHD6|Input_THBS3',
#   'Input_CHD8|Input_MAD1L1',
#   'Input_CHD8|Input_PTPRZ1',
#   'Input_CHEK2|Input_DGAT2',
#   'Input_CHL1|Input_MLKL',
#   'Input_CHL1|Input_SLC17A8',
#   'Input_CHRNA10|Input_SIRT5',
#   'Input_CHRNA10|Input_SLC6A5',
#   'Input_CHRNA4|Input_SLC17A9',
#   'Input_CHRNA5|Input_P4HA2',
#   'Input_CHRNA6|Input_KCNE3',
#   'Input_CHRNA7|Input_DCT',
#   'Input_CHRNA9|Input_UGDH',
#   'Input_CHRND|Input_EP300',
#   'Input_CHRND|Input_RTTN',
#   'Input_CHRNE|Input_UQCRC1',
#   'Input_CHRNG|Input_GPD2',
#   'Input_CHRNG|Input_NACA2',
#   'Input_CIAO3|Input_DHRS4L2',
#   'Input_CLCN1|Input_OR2F1',
#   'Input_CLCN3|Input_DNAH9',
#   'Input_CLDN10|Input_MEGF6',
#   'Input_CLDN16|Input_CREBBP',
#   'Input_CLDN1|Input_SRCAP',
#   'Input_CLDN9|Input_HABP2',
#   'Input_CLIC6|Input_FLG2',
#   'Input_CLN3|Input_DQX1',
#   'Input_CLN6|Input_ZNF100',
#   'Input_CLPTM1|Input_RCBTB2',
#   'Input_CLSTN2|Input_KIF24',
#   'Input_CLUH|Input_RIMS1',
#   'Input_CLUH|Input_TTPA',
#   'Input_CMA1|Input_PLA2G15',
#   'Input_CNBD2|Input_SLC24A4',
# ...
#   'Input_MBTPS1|Input_SKIC2',
#   'Input_MCCC1|Input_NDUFA8',
#   'Input_MCCC2|Input_SLCO1B1',
#   'Input_MCOLN2|Input_PFKFB1',
#   'Input_MFAP3L|Input_RYR1',
#   'Input_MFSD1|Input_SPATA5L1',
#   'Input_MFSD5|Input_PNPLA7',
#   'Input_MGAM|Input_STON1',
#   'Input_MICAL3|Input_OCA2',
#   'Input_MIGA1|Input_OCA2',
#   'Input_MLH1|Input_TRIM17',
#   'Input_MME|Input_RDX',
#   'Input_MOCOS|Input_MYO10',
#   'Input_MOCS1|Input_RASA1',
#   'Input_MOCS1|Input_TNK2',
#   'Input_MOXD1|Input_NEB',
#   'Input_MPRIP|Input_MYO15A',
#   'Input_MPZL2|Input_MSH2',
#   'Input_MRE11|Input_PFKL',
#   'Input_MTMR2|Input_RP1L1',
#   'Input_MTMR7|Input_WNT16',
#   'Input_MTMR9|Input_TBX3',
#   'Input_MUC17|Input_TMEM67',
#   'Input_MUC4|Input_SLC7A13',
#   'Input_MVK|Input_POLG',
#   'Input_MYH10|Input_OTOL1',
#   'Input_MYH11|Input_SYNJ1',
#   'Input_MYH13|Input_RAVER1',
#   'Input_MYH2|Input_OR6C75',
#   'Input_MYH2|Input_PC',
#   'Input_MYH4|Input_ZNF276',
#   'Input_MYH6|Input_SGSM3',
#   'Input_MYH7B|Input_SI|Input_TTN',
#   'Input_MYH7|Input_NTN3',
#   'Input_MYH7|Input_PTK2',
#   'Input_MYH9|Input_RGN',
#   'Input_MYO1B|Input_TNK2',
#   'Input_MYO1C|Input_SELENOH',
#   'Input_MYO1C|Input_SULT1C3',
#   'Input_MYO1G|Input_SEPTIN4',
#   'Input_MYO3A|Input_PCDHA6',
#   'Input_MYO3A|Input_STARD9',
#   'Input_MYO3B|Input_PIK3C2B',
#   'Input_MYO5B|Input_P4HA3',
#   'Input_MYO5B|Input_TTLL6',
#   'Input_MYO5C|Input_PI4K2B',
#   'Input_MYO7A|Input_SLC4A9',
#   'Input_MYO9A|Input_ZMYM5',
#   'Input_MYOM2|Input_SLC12A8',
#   'Input_NACA2|Input_NEFM',
#   'Input_NEB|Input_POMGNT2',
#   'Input_NEFM|Input_RGL4',
#   'Input_NEFM|Input_SETD1B',
#   'Input_NEFM|Input_ZNF511',
#   'Input_NIPAL2|Input_SCN1A',
#   'Input_NOB1|Input_OBSCN',
#   'Input_NOD2|Input_SDK1',
#   'Input_NOX5|Input_TULP4',
#   'Input_NR2F6|Input_USH2A',
#   'Input_NR4A1|Input_PHYH',
#   'Input_NRP2|Input_PDE3B',
#   'Input_NRP2|Input_VEPH1',
#   'Input_NRXN1|Input_SLC12A9',
#   'Input_NT5C1A|Input_RP1L1',
#   'Input_NUP133|Input_OBSCN',
#   'Input_OR2T27|Input_PDPR',
#   'Input_OR52K1|Input_SCN10A',
#   'Input_OR8J1|Input_SRCAP',
#   'Input_OTOF|Input_TONSL',
#   'Input_PAH|Input_PIGX',
#   'Input_PAH|Input_SNX5',
#   'Input_PAK4|Input_PYGM',
#   'Input_PAK6|Input_PLA2G4D',
#   'Input_PAX1|Input_PIK3C2A',
#   'Input_PAX9|Input_SLC12A9',
#   'Input_PCDHGA3|Input_SERPINA12',
#   'Input_PCDHGA3|Input_THNSL1',
#   'Input_PCK2|Input_UBR4',
#   'Input_PCSK9|Input_RP1L1',
#   'Input_PC|Input_SLC25A18',
#   'Input_PC|Input_SLC25A20',
#   'Input_PES1|Input_SARDH',
#   'Input_PEX6|Input_PLA2R1',
#   'Input_PFAS|Input_SCUBE1',
#   'Input_PFKFB1|Input_SAXO2',
#   'Input_PFKFB1|Input_ZNF708',
#   'Input_PIF1|Input_STAB1',
#   'Input_PKD1L1|Input_TRPM5',
#   'Input_PKD1L3|Input_POTEJ',
#   'Input_PKD1L3|Input_QARS1',
#   'Input_PKD2|Input_UPK1A',
#   'Input_PKDREJ|Input_XDH',
#   'Input_PKM|Input_PPEF2',
#   'Input_PKP3|Input_RYR2',
#   'Input_PLA2G6|Input_PLEKHH1',
#   'Input_PLEKHH1|Input_PPEF2',
#   'Input_PLOD3|Input_TPMT',
#   'Input_PLXNB3|Input_TNS1',
#   'Input_PMM2|Input_SBF1',
#   'Input_PMM2|Input_SPTBN5',
#   'Input_PNKD|Input_SLC12A3',
#   'Input_POLG|Input_TLR1',
#   'Input_POLQ|Input_RFT1',
#   'Input_POMT1|Input_TNNI3K',
#   'Input_POR|Input_SORL1',
#   'Input_POSTN|Input_SPG11',
#   'Input_POTEI|Input_TCF3',
#   'Input_PPP1CC|Input_TTC28',
#   'Input_PRPH|Input_TRPA1',
#   'Input_PRSS12|Input_SLC22A2',
#   'Input_PRSS12|Input_SLC7A11',
#   'Input_PRSS33|Input_SBF2',
#   'Input_PTK2|Input_SLC12A9',
#   'Input_PUSL1|Input_SCN9A',
#   'Input_PXYLP1|Input_RYR3',
#   'Input_PYGL|Input_ZNF573',
#   'Input_RAG2|Input_SMAD1',
#   'Input_RALGAPA2|Input_TBRG1',
#   'Input_RARG|Input_SLC12A7',
#   'Input_RNF213|Input_TENM3',
#   'Input_RNF220|Input_ST18',
#   'Input_ROBO2|Input_SLC7A14',
#   'Input_RSF1|Input_TDRD6',
#   'Input_RYR1|Input_WIPF1',
#   'Input_RYR1|Input_ZSCAN31',
#   'Input_RYR3|Input_ZNF850',
#   'Input_SARDH|Input_SLC17A4',
#   'Input_SCARA5|Input_SCN11A',
#   'Input_SCN5A|Input_SLC26A1',
#   'Input_SCN5A|Input_ZNF701',
#   'Input_SCN7A|Input_TAP1',
#   'Input_SCPEP1|Input_SPTB',
#   'Input_SCUBE2|Input_ZFYVE28',
#   'Input_SGCG|Input_XAB2',
#   'Input_SH3TC1|Input_TCHH',
#   'Input_SLC22A25|Input_VNN1',
#   'Input_SLC25A34|Input_TEX14',
#   'Input_SLC26A4|Input_TMEM191C',
#   'Input_SLC26A6|Input_SOAT2',
#   'Input_SLC27A3|Input_USH2A',
#   'Input_SLC2A5|Input_SPG11',
#   'Input_SLC34A3|Input_ZNF546',
#   'Input_SLC5A10|Input_TMEM68',
#   'Input_SLC6A18|Input_VPS13C',
#   'Input_SLC6A19|Input_TFEB',
#   'Input_SLC7A14|Input_SULF1',
#   'Input_SLC7A4|Input_TCEA3',
#   'Input_SLC8A3|Input_UCP1',
#   'Input_SMTN|Input_ZNF208',
#   'Input_SMYD4|Input_SPAG9',
#   'Input_SOX6|Input_VDR',
#   'Input_SPTBN5|Input_TUBA3E',
#   'Input_SPTB|Input_TOM1L2',
#   'Input_SREBF1|Input_UGT1A7',
#   'Input_STAB1|Input_VAX2',
#   'Input_TAS1R3|Input_ZNF528',
#   'Input_TCAP|Input_TLL2',
#   'Input_TECTA|Input_TMPRSS13',
#   'Input_TENM1|Input_URB1',
#   'Input_TEX15|Input_ZFHX3',
#   'Input_TGFBI|Input_TTC7A',
#   'Input_TRIM63|Input_ZNF442',
#   'Input_TRPM2|Input_UTRN',
#   'Input_TTC28|Input_ZGPAT',
#   'Input_TTN|Input_TULP4',
#   'Input_TUBA8|Input_UNC13C',
#   'Input_VANGL1|Input_VWA2',
#   'Input_VAX2|Input_WDR19',
#   'Input_ZNF100|Input_ZNF534',
#   'Input_ZNF335|Input_ZNF442'},
#  (('british', 'british_male'),
#   ('british_female',
#    'pre_menopause',
#    'post_menopause')): {'Input_ABCC10|Input_MYH13|Input_TTN',
#   'Input_ACO1|Input_HELZ',
#   'Input_ADAMTS2|Input_ATP6V1H',
#   'Input_ADAMTSL3|Input_HFM1',
#   'Input_AGER|Input_POTEE',
#   'Input_ANKRD33|Input_PFKM',
#   'Input_APIP|Input_PTPRZ1',
#   'Input_ATP2B2|Input_PEX5',
#   'Input_ATP2B4|Input_LGR6',
#   'Input_ATP4A|Input_SERPINA4',
#   'Input_ATRN|Input_HSF4',
#   'Input_BCO2|Input_SLC6A19',
#   'Input_BMP8A|Input_UBXN6',
#   'Input_C11orf54|Input_C8A',
#   'Input_CARD6|Input_SCUBE1',
#   'Input_CCDC150|Input_INHBE',
#   'Input_CHDH|Input_COL11A2',
#   'Input_CHRNA6|Input_NFE2L2',
#   'Input_CLCN2|Input_KDM1B',
#   'Input_COL4A4|Input_USP35',
#   'Input_CTU2|Input_ZNF681',
#   'Input_CWF19L2|Input_MYH10',
#   'Input_DNHD1|Input_DYRK3',
#   'Input_DRG1|Input_GRHPR|Input_SFI1',
#   'Input_DUXA|Input_RAD50',
#   'Input_ENTPD3|Input_GALT',
#   'Input_EPHA8|Input_FLCN',
#   'Input_EXT2|Input_KIF26B',
#   'Input_FAHD1|Input_SLC45A4',
#   'Input_GATA3|Input_MTMR7',
#   'Input_GDPD4|Input_KLHL38',
#   'Input_GLRB|Input_SRRM2',
#   'Input_GRIA4|Input_PLA2G4B',
#   'Input_GTPBP1|Input_SCUBE1',
#   'Input_HS3ST1|Input_MYO7A',
#   'Input_LMTK2|Input_ZFP37',
#   'Input_MFSD9|Input_VPS35L',
#   'Input_MIB2|Input_VWA8',
#   'Input_NOC3L|Input_SCN5A',
#   'Input_NPL|Input_PPP1R13B',
#   'Input_NSD1|Input_PANK1',
#   'Input_OR2T2|Input_OR6F1',
#   'Input_PDE11A|Input_PTPN13',
#   'Input_PEX10|Input_SIX4',
#   'Input_PGAP3|Input_ROM1',
#   'Input_PKHD1L1|Input_SLC26A1|Input_TTN',
#   'Input_SCN10A|Input_TBCD',
#   'Input_XPA|Input_ZNF226'},
#  (('british', 'british_female'),
#   ('british_male',
#    'pre_menopause',
#    'post_menopause')): {'Input_ABCA13|Input_LRP2|Input_SCN10A',
#   'Input_ABCA7|Input_FLNC|Input_GRM6',
#   'Input_ABCC10|Input_CACNA1H|Input_CUBN',
#   'Input_ABCC3|Input_RYR3|Input_SLC12A3',
#   'Input_ABCC8|Input_TMEM185A',
#   'Input_ACACB|Input_LRP2|Input_RYR1',
#   'Input_ACAP3|Input_SLC7A8|Input_TAS1R3',
#   'Input_ACOT1|Input_WNK4',
#   'Input_ADAMTS17|Input_MUC16',
#   'Input_ADAMTS20|Input_KISS1R',
#   'Input_ADAMTS4|Input_POU4F2',
#   'Input_AGFG1|Input_KCNQ3',
#   'Input_ALPI|Input_INCA1',
#   'Input_ANKRD18B|Input_KIF19',
#   'Input_ARSL|Input_ATP7B|Input_MYO7A',
#   'Input_ATAD3B|Input_RBL2|Input_TAS1R3',
#   'Input_ATP1A4|Input_NR2E1',
#   'Input_ATP7B|Input_DST|Input_MGAM',
#   'Input_BCHE|Input_CYP1A1',
#   'Input_BOC|Input_TEX9',
#   'Input_CACNA1F|Input_COL6A3|Input_MYO15A',
#   'Input_CCDC33|Input_SERPINA6',
#   'Input_CEP290|Input_COL6A3|Input_KIF26A',
#   'Input_CFTR|Input_FLNC|Input_SLC6A20',
#   'Input_CHD7|Input_FOXJ1',
#   'Input_CLDN19|Input_NFATC3',
#   'Input_CLN5|Input_STS',
#   'Input_CLUH|Input_NGB',
#   'Input_CNPY4|Input_SLC52A3',
#   'Input_COL18A1|Input_ULBP3',
#   'Input_COL4A2|Input_MYH13|Input_SACS',
#   'Input_CPNE1|Input_NR1H3',
#   'Input_CPT1B|Input_FBN3|Input_TTN',
#   'Input_CYP4X1|Input_MADD',
#   'Input_DBX1|Input_MYBPC3',
#   'Input_DHRS13|Input_RPL23A',
#   'Input_DHRS4|Input_TDO2',
#   'Input_DIPK1B|Input_ROM1',
#   'Input_DNAH5|Input_FLNB|Input_HERC1',
#   'Input_DNAH5|Input_FLNB|Input_SPTB',
#   'Input_DNAH5|Input_HERC1',
#   'Input_DNAH5|Input_PAH|Input_USH2A',
#   'Input_DSG3|Input_STAB1',
#   'Input_DSG4|Input_RARS2',
#   'Input_DTX2|Input_MAGI2',
#   'Input_DUOX1|Input_MYH6|Input_MYO15A',
#   'Input_DUS3L|Input_OC90',
#   'Input_ECEL1|Input_PCDHGA11|Input_PCDHGA5',
#   'Input_EGFLAM|Input_FBN3|Input_MCCC2',
#   'Input_ELMO3|Input_NAPG',
#   'Input_FAHD2B|Input_USP2',
#   'Input_FBN3|Input_SCN11A|Input_TTN',
#   'Input_FGD5|Input_VILL',
#   'Input_FLNB|Input_KLKB1|Input_TENM4',
#   'Input_FLNC|Input_PKHD1L1|Input_SCN11A',
#   'Input_GH1|Input_HK1',
#   'Input_GINS2|Input_UNC13D',
#   'Input_GRM1|Input_NME8',
#   'Input_GRM6|Input_SCN7A|Input_TTN',
#   'Input_HMCN1|Input_LDLRAD3',
#   'Input_HOXC12|Input_UGT1A7',
#   'Input_HYDIN|Input_PIR',
#   'Input_IGDCC3|Input_PPP1R9A',
#   'Input_IL1RAP|Input_TRAP1',
#   'Input_IL5RA|Input_POLK',
#   'Input_ITPA|Input_KSR2',
#   'Input_ITSN2|Input_TG|Input_TTN',
#   'Input_KCNJ15|Input_MEOX1',
#   'Input_KCNQ1|Input_MMADHC',
#   'Input_KIF15|Input_SYN3',
#   'Input_LPCAT2|Input_MMP2',
#   'Input_LRRC43|Input_PTCH2',
#   'Input_MAN2C1|Input_TEKT2',
#   'Input_MAOB|Input_TAS1R2',
#   'Input_MCAT|Input_OXNAD1',
#   'Input_MECP2|Input_SPRY3',
#   'Input_MFSD12|Input_RASSF4',
#   'Input_MPL|Input_PPIH',
#   'Input_MRPL2|Input_PRDM16',
#   'Input_MX2|Input_P4HTM',
#   'Input_MYH1|Input_NOTCH4|Input_RYR2',
#   'Input_MYH6|Input_MYH9|Input_TTN',
#   'Input_MYO15A|Input_RPL23A',
#   'Input_MYO7B|Input_RYR3|Input_TENM4',
#   'Input_NDUFA13|Input_ZNF493',
#   'Input_NFASC|Input_TSTD2',
#   'Input_NPRL2|Input_TRIM59',
#   'Input_NR3C2|Input_PIK3AP1',
#   'Input_NRL|Input_ZEB2',
#   'Input_OGFOD3|Input_PCYT2',
#   'Input_PCDHB2|Input_SPATA24',
#   'Input_PIGV|Input_PSG9',
#   'Input_PTP4A3|Input_STARD8',
#   'Input_SPINK5|Input_UGT1A9',
#   'Input_THAP2|Input_ZNF534'},
#  (('british', 'pre_menopause'),
#   ('british_male', 'british_female', 'post_menopause')): set(),
#  (('british', 'post_menopause'),
#   ('british_male',
#    'british_female',
#    'pre_menopause')): {'Input_ACRBP|Input_KCNA5',
#   'Input_ADCK2|Input_FBN2',
#   'Input_ARFGEF2|Input_CDAN1',
#   'Input_C9|Input_SARS2',
#   'Input_CYP1A1|Input_FGA',
#   'Input_DNAH8|Input_TSNARE1',
#   'Input_DUOX1|Input_MYH6',
#   'Input_MFAP4|Input_SERPINA6',
#   'Input_MYH6|Input_SFXN5',
#   'Input_PGM2|Input_RFC1'},
#  (('british_male', 'british_female'),
#   ('british', 'pre_menopause', 'post_menopause')): set(),
#  (('british_male', 'pre_menopause'),
#   ('british', 'british_female', 'post_menopause')): set(),
#  (('british_male', 'post_menopause'),
#   ('british', 'british_female', 'pre_menopause')): set(),
#  (('british_female', 'pre_menopause'),
#   ('british', 'british_male', 'post_menopause')): {'Input_DPYD|Input_NUDT1'},
#  (('british_female', 'post_menopause'),
#   ('british', 'british_male', 'pre_menopause')): {'Input_ABCA3|Input_MYL6',
#   'Input_ABCA9|Input_HERC5',
#   'Input_ABCC11|Input_POMC',
#   'Input_ABCF1|Input_MTMR2',
#   'Input_ABCF3|Input_COL1A1',
#   'Input_ACACB|Input_TTC28|Input_TTN',
#   'Input_ACAD11|Input_MFAP2',
#   'Input_ACE|Input_CDH16',
#   'Input_ACSF3|Input_ALDH1L1',
#   'Input_ADA|Input_CEL',
#   'Input_ADGRL1|Input_HMCN2',
#   'Input_AGBL4|Input_SCN11A',
#   'Input_ALDH8A1|Input_GRIP1',
#   'Input_ALDOB|Input_SDHB',
#   'Input_ALS2|Input_MYOM2',
#   'Input_ANKRD12|Input_HCN3',
#   'Input_ANKRD18A|Input_CROT',
#   'Input_ANKRD35|Input_FLII',
#   'Input_ATG9B|Input_F11',
#   'Input_ATP1A4|Input_UGT1A9',
#   'Input_ATP8B3|Input_TK2',
#   'Input_ATRN|Input_XIRP2',
#   'Input_BBX|Input_SHC1',
#   'Input_BEST2|Input_PTPRN',
#   'Input_C1orf50|Input_SZT2',
#   'Input_CAPN13|Input_SLC26A11',
#   'Input_CCDC146|Input_SLC2A8',
#   'Input_CCDC66|Input_ZNF717',
#   'Input_CCT6B|Input_DLL4',
#   'Input_CEL|Input_INPP5E',
#   'Input_CEP152|Input_DUOX1',
#   'Input_CEP95|Input_OR8J1',
#   'Input_CHD2|Input_CREBBP',
#   'Input_CHMP3|Input_SETD1B',
#   'Input_CLDN20|Input_PLEKHH1',
#   'Input_CLEC11A|Input_MYH6',
#   'Input_CNTNAP2|Input_SLC24A2',
#   'Input_COBLL1|Input_OR2T2',
#   'Input_COL14A1|Input_TRPT1',
#   'Input_COL17A1|Input_TCOF1',
#   'Input_COL5A3|Input_MOCS3',
#   'Input_COMP|Input_PEAR1',
#   'Input_CREB3|Input_LRP3',
#   'Input_CRYBG2|Input_TNS2',
#   'Input_CYP4B1|Input_OPRL1',
#   'Input_CYP4B1|Input_TPSD1',
#   'Input_CYP7B1|Input_GALNT11',
#   'Input_D2HGDH|Input_OLFML2B',
#   'Input_DCAF6|Input_SELE',
#   'Input_DHX34|Input_SLC5A5',
#   'Input_DNMT3A|Input_NOTCH2',
#   'Input_DOP1B|Input_WDR19',
#   'Input_DYSF|Input_OR2T8',
#   'Input_ENPEP|Input_KLHL1',
#   'Input_FANCM|Input_PPP1R9A',
#   'Input_FBLN2|Input_SLC6A20',
#   'Input_FCRL6|Input_LMNA',
#   'Input_FGD6|Input_TLN1',
#   'Input_FHL5|Input_NPHP4',
#   'Input_FLNA|Input_TTC28|Input_TTN',
#   'Input_FMNL2|Input_SLC3A1',
#   'Input_GANC|Input_JMJD7',
#   'Input_GATA5|Input_MYH13',
#   'Input_GBA1|Input_LTBP1',
#   'Input_GFUS|Input_NPC1',
#   'Input_GLDC|Input_KLHL21',
#   'Input_GSDMC|Input_PLEC',
#   'Input_GSTZ1|Input_PKHD1L1',
#   'Input_HCN1|Input_RAD54L',
#   'Input_HOXC10|Input_TH',
#   'Input_HPS5|Input_ZNF540',
#   'Input_IFT88|Input_SLC4A5',
#   'Input_IGFN1|Input_TNC',
#   'Input_ITLN1|Input_SLC6A16',
#   'Input_KCNH4|Input_TGM5',
#   'Input_KCNK10|Input_SCUBE2',
#   'Input_KIF14|Input_SH3BP2',
#   'Input_KIF5B|Input_TINAG',
#   'Input_KLKB1|Input_PAX9',
#   'Input_KRT39|Input_MIPEP',
#   'Input_KRT83|Input_L1TD1',
#   'Input_KRT8|Input_NAA16',
#   'Input_LIPK|Input_MME',
#   'Input_LRRD1|Input_TNK2',
#   'Input_LTBP1|Input_PALB2',
#   'Input_MELTF|Input_TGM3',
#   'Input_MGMT|Input_MTMR9',
#   'Input_MICU3|Input_SCN11A',
#   'Input_MYH10|Input_TPRN',
#   'Input_MYH11|Input_SERGEF',
#   'Input_MYH13|Input_OBSCN|Input_RYR3',
#   'Input_MYL3|Input_POMGNT2',
#   'Input_MYO18A|Input_SLC10A2',
#   'Input_NCAN|Input_PASK',
#   'Input_NELL1|Input_TRH',
#   'Input_NELL1|Input_VPS13D',
#   'Input_NOTCH1|Input_NRCAM',
#   'Input_NRAP|Input_ZNF717',
#   'Input_OBSCN|Input_STK17A',
#   'Input_OCA2|Input_UBXN6',
#   'Input_PDE6A|Input_TRIT1',
#   'Input_POLQ|Input_SMPDL3B',
#   'Input_RHBDF1|Input_RNF19A',
#   'Input_RHOBTB3|Input_SLCO6A1',
#   'Input_RSF1|Input_TCHP',
#   'Input_SEC31B|Input_UNC93A',
#   'Input_SULT1B1|Input_TMPRSS11F',
#   'Input_UACA|Input_UMPS'},
#  (('pre_menopause', 'post_menopause'),
#   ('british', 'british_male', 'british_female')): set(),
#  (('british', 'british_male', 'british_female'),
#   ('pre_menopause', 'post_menopause')): set(),
#  (('british', 'british_male', 'pre_menopause'),
#   ('british_female', 'post_menopause')): set(),
#  (('british', 'british_male', 'post_menopause'),
#   ('british_female', 'pre_menopause')): set(),
#  (('british', 'british_female', 'pre_menopause'),
#   ('british_male', 'post_menopause')): set(),
#  (('british', 'british_female', 'post_menopause'),
#   ('british_male', 'pre_menopause')): {'Input_ABCA13|Input_DDX60L',
#   'Input_ABCB6|Input_LIPE',
#   'Input_ALDH3B2|Input_SPTBN5',
#   'Input_ANO2|Input_CD9',
#   'Input_ATP7A|Input_PHF21B',
#   'Input_AZGP1|Input_MYH7B',
#   'Input_CACNA1C|Input_GEMIN5',
#   'Input_CYP7B1|Input_TULP3',
#   'Input_DNAH3|Input_PICK1',
#   'Input_FAHD2B|Input_SYNE1',
#   'Input_KRT74|Input_UGT2B10',
#   'Input_LINGO4|Input_TMEM102',
#   'Input_MTMR3|Input_TENM2',
#   'Input_PTK2B|Input_SERPINB9',
#   'Input_TGM4|Input_THRB'},
#  (('british', 'pre_menopause', 'post_menopause'),
#   ('british_male', 'british_female')): set(),
#  (('british_male', 'british_female', 'pre_menopause'),
#   ('british', 'post_menopause')): set(),
#  (('british_male', 'british_female', 'post_menopause'),
#   ('british', 'pre_menopause')): set(),
#  (('british_male', 'pre_menopause', 'post_menopause'),
#   ('british', 'british_female')): set(),
#  (('british_female', 'pre_menopause', 'post_menopause'),
#   ('british', 'british_male')): set(),
#  (('british', 'british_male', 'british_female', 'pre_menopause'),
#   ('post_menopause',)): set(),
#  (('british', 'british_male', 'british_female', 'post_menopause'),
#   ('pre_menopause',)): set(),
#  (('british', 'british_male', 'pre_menopause', 'post_menopause'),
#   ('british_female',)): set(),
#  (('british', 'british_female', 'pre_menopause', 'post_menopause'),
#   ('british_male',)): set(),
#  (('british_male', 'british_female', 'pre_menopause', 'post_menopause'),
#   ('british',)): set(),
#  (('british',
#    'british_male',
#    'british_female',
#    'pre_menopause',
#    'post_menopause'),
#   ()): set()}

# %%
wbf_postm_intersects = unique_intersects[('white_british_female', 'post_menopause',), ('white_british', 'white_british_male', 'pre_menopause',)]

# %%
save_file = "/data5/deepro/ukbiobank/papers/bmi_project/4_characterization/shared/data/overlap/wbfemale_postm_overlap.txt"

with open(save_file, "w") as f:
    for combo in wbf_postm_intersects:
        f.write(f"{combo}\n")
