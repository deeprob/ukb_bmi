# %%
import requests
import pandas as pd

# %%
def get_ppi_score(genes):
    request_url = "https://string-db.org/api/tsv-no-header/ppi_enrichment?"
    params = {
        "identifiers" : "%0d".join(genes), # your proteins
        "species" : 9606, # species NCBI identifier 
        "caller_identity" : "www.awesome_app.org" # your app name
    }
    response = requests.post(request_url, data=params)
    # print(response.text)
    # header_names = ["number_of_nodes", "number_of_edges", "average_node_degree", "local_clustering_coefficient", "expected_number_of_edges", "p_value"]
    number_of_nodes, number_of_edges, average_node_degree, local_clustering_coefficient, expected_number_of_edges, p_value = list(map(float, response.text.strip().split("\n")[0].split("\t")))
    # df = pd.DataFrame([line.split("\t") for line in response.text.strip().split("\n")], columns=header_names)
    # df["combo"] = "|".join(genes)
    return pd.Series({
        "number_of_nodes": number_of_nodes,
        "number_of_edges": number_of_edges,
        "average_node_degree": average_node_degree,
        "local_clustering_coefficient": local_clustering_coefficient,
        "expected_number_of_edges": expected_number_of_edges,
        "p_value": p_value 
    })

# %%
combo_files = [
    "/data6/deepro/ukb_bmi/2_rarecomb/data/british/combo2.csv",
    "/data6/deepro/ukb_bmi/2_rarecomb/data/british/combo3.csv"
]

combo_df = pd.concat([pd.read_csv(cf).loc[:, ["uniq_items"]] for cf in combo_files])

# %%
combo_df["uniq_items"] = combo_df.uniq_items.str.replace("Input_", "").str.split("|")

# %%
combo_df = pd.concat((combo_df, combo_df.uniq_items.apply(get_ppi_score)), axis=1)

# %%
combo_df.loc[combo_df.p_value<0.05].uniq

# %%
combo_df.loc[combo_df.p_value<0.05].sort_values("p_value")
# Out:
#                    uniq_items  number_of_nodes  number_of_edges  \
# 580   [ABCB4, UGT1A4, UGT1A7]              3.0              3.0
# 595   [ABCB4, UGT1A1, UGT1A7]              3.0              3.0
# 596   [ABCB4, UGT1A1, UGT1A4]              3.0              3.0
# 1050  [ABCB4, UGT1A6, UGT1A7]              3.0              3.0
# 1051  [ABCB4, UGT1A4, UGT1A6]              3.0              3.0
# ...                       ...              ...              ...
# 226              [GRM1, NME8]              2.0              1.0
# 275       [ABCA12, RYR1, TTN]              3.0              1.0
# 383   [CACNA1S, MYO1C, MYO7A]              3.0              1.0
# 177        [RYR2, TENM4, TTN]              3.0              1.0
# 4        [DNAH5, DNAJC6, TTN]              3.0              1.0
#
#       average_node_degree  local_clustering_coefficient  \
# 580                  2.00                         1.000
# 595                  2.00                         1.000
# 596                  2.00                         1.000
# 1050                 2.00                         1.000
# 1051                 2.00                         1.000
# ...                   ...                           ...
# 226                  1.00                         1.000
# 275                  0.67                         0.667
# 383                  0.67                         0.667
# 177                  0.67                         0.667
# 4                    0.67                         0.667
#
#       expected_number_of_edges   p_value
# 580                        0.0  0.000005
# 595                        0.0  0.000005
# 596                        0.0  0.000005
# 1050                       0.0  0.000005
# 1051                       0.0  0.000006
# ...                        ...       ...
# 226                        0.0  0.047500
# 275                        0.0  0.047700
# 383                        0.0  0.049000
# 177                        0.0  0.049700
# 4                          0.0  0.049800
#
# [375 rows x 7 columns]

# %%
combo_df.loc[combo_df.p_value<0.05].sort_values("p_value").head(60)
# Out:
#                        uniq_items  number_of_nodes  number_of_edges  \
# 580       [ABCB4, UGT1A4, UGT1A7]              3.0              3.0
# 595       [ABCB4, UGT1A1, UGT1A7]              3.0              3.0
# 596       [ABCB4, UGT1A1, UGT1A4]              3.0              3.0
# 1050      [ABCB4, UGT1A6, UGT1A7]              3.0              3.0
# 1051      [ABCB4, UGT1A4, UGT1A6]              3.0              3.0
# 1054      [ABCB4, UGT1A1, UGT1A6]              3.0              3.0
# 199         [ABCA4, MYO7A, MYO7B]              3.0              2.0
# 947     [ECEL1, PCDHGC4, PCDHGC5]              3.0              1.0
# 832    [ECEL1, PCDHGA11, PCDHGB7]              3.0              1.0
# 187     [ECEL1, PCDHGA5, PCDHGA8]              3.0              1.0
# 232    [ECEL1, PCDHGA10, PCDHGA8]              3.0              1.0
# 701     [ECEL1, PCDHGA6, PCDHGA8]              3.0              1.0
# 785     [ECEL1, PCDHGA8, PCDHGA9]              3.0              1.0
# 617     [ECEL1, PCDHGA1, PCDHGA5]              3.0              1.0
# 610     [ECEL1, PCDHGA5, PCDHGA7]              3.0              1.0
# 712     [ECEL1, PCDHGA5, PCDHGA6]              3.0              1.0
# 581       [ABCB4, UGT1A3, UGT1A4]              3.0              2.0
# 344    [ECEL1, PCDHGA11, PCDHGA3]              3.0              1.0
# 172       [ABCB4, UGT1A3, UGT1A7]              3.0              2.0
# 355   [ECEL1, PCDHGA11, PCDHGA12]              3.0              1.0
# 702     [ECEL1, PCDHGA6, PCDHGA7]              3.0              1.0
# 799     [ECEL1, PCDHGA5, PCDHGA9]              3.0              1.0
# 861     [ECEL1, PCDHGA1, PCDHGC3]              3.0              1.0
# 134    [ECEL1, PCDHGA10, PCDHGB5]              3.0              1.0
# 126     [ECEL1, PCDHGB4, PCDHGB5]              3.0              1.0
# 825     [ECEL1, PCDHGB2, PCDHGB7]              3.0              1.0
# 624     [ECEL1, PCDHGA1, PCDHGA3]              3.0              1.0
# 593       [ABCB4, UGT1A1, UGT1A3]              3.0              2.0
# 1048      [ABCB4, UGT1A3, UGT1A6]              3.0              2.0
# 728    [ECEL1, PCDHGA12, PCDHGA7]              3.0              1.0
# 509     [ECEL1, PCDHGA2, PCDHGA3]              3.0              1.0
# 798     [ECEL1, PCDHGA3, PCDHGA9]              3.0              1.0
# 136     [ECEL1, PCDHGB3, PCDHGB5]              3.0              1.0
# 855     [ECEL1, PCDHGA3, PCDHGC3]              3.0              1.0
# 797    [ECEL1, PCDHGA12, PCDHGA9]              3.0              1.0
# 341       [ABCB4, UGT1A4, UGT1A9]              3.0              2.0
# 635     [ECEL1, PCDHGA7, PCDHGB3]              3.0              1.0
# 340       [ABCB4, UGT1A7, UGT1A9]              3.0              2.0
# 637     [ECEL1, PCDHGB3, PCDHGB4]              3.0              1.0
# 638     [ECEL1, PCDHGA2, PCDHGB3]              3.0              1.0
# 911     [ECEL1, PCDHGA4, PCDHGB7]              3.0              1.0
# 862     [ECEL1, PCDHGB3, PCDHGC3]              3.0              1.0
# 597       [ABCB4, UGT1A1, UGT1A9]              3.0              2.0
# 788     [ECEL1, PCDHGA9, PCDHGB3]              3.0              1.0
# 707     [ECEL1, PCDHGA6, PCDHGB2]              3.0              1.0
# 284     [ECEL1, PCDHGA7, PCDHGB1]              3.0              1.0
# 657     [ECEL1, PCDHGA2, PCDHGB2]              3.0              1.0
# 663     [ECEL1, PCDHGB2, PCDHGB4]              3.0              1.0
# 129     [ECEL1, PCDHGB2, PCDHGB5]              3.0              1.0
# 128     [ECEL1, PCDHGB1, PCDHGB5]              3.0              1.0
# 287     [ECEL1, PCDHGA2, PCDHGB1]              3.0              1.0
# 286     [ECEL1, PCDHGB1, PCDHGB4]              3.0              1.0
# 895     [ECEL1, PCDHGA4, PCDHGA8]              3.0              1.0
# 1052      [ABCB4, UGT1A6, UGT1A9]              3.0              2.0
# 641     [ECEL1, PCDHGA3, PCDHGB3]              3.0              1.0
# 796     [ECEL1, PCDHGA9, PCDHGB1]              3.0              1.0
# 789     [ECEL1, PCDHGA9, PCDHGB2]              3.0              1.0
# 685     [ECEL1, PCDHGB2, PCDHGB6]              3.0              1.0
# 894     [ECEL1, PCDHGA4, PCDHGA5]              3.0              1.0
# 731    [ECEL1, PCDHGA12, PCDHGB1]              3.0              1.0
#
#       average_node_degree  local_clustering_coefficient  \
# 580                  2.00                         1.000
# 595                  2.00                         1.000
# 596                  2.00                         1.000
# 1050                 2.00                         1.000
# 1051                 2.00                         1.000
# 1054                 2.00                         1.000
# 199                  1.33                         0.667
# 947                  0.67                         0.667
# 832                  0.67                         0.667
# 187                  0.67                         0.667
# 232                  0.67                         0.667
# 701                  0.67                         0.667
# 785                  0.67                         0.667
# 617                  0.67                         0.667
# 610                  0.67                         0.667
# 712                  0.67                         0.667
# 581                  1.33                         0.667
# 344                  0.67                         0.667
# 172                  1.33                         0.667
# 355                  0.67                         0.667
# 702                  0.67                         0.667
# 799                  0.67                         0.667
# 861                  0.67                         0.667
# 134                  0.67                         0.667
# 126                  0.67                         0.667
# 825                  0.67                         0.667
# 624                  0.67                         0.667
# 593                  1.33                         0.667
# 1048                 1.33                         0.667
# 728                  0.67                         0.667
# 509                  0.67                         0.667
# 798                  0.67                         0.667
# 136                  0.67                         0.667
# 855                  0.67                         0.667
# 797                  0.67                         0.667
# 341                  1.33                         0.667
# 635                  0.67                         0.667
# 340                  1.33                         0.667
# 637                  0.67                         0.667
# 638                  0.67                         0.667
# 911                  0.67                         0.667
# 862                  0.67                         0.667
# 597                  1.33                         0.667
# 788                  0.67                         0.667
# 707                  0.67                         0.667
# 284                  0.67                         0.667
# 657                  0.67                         0.667
# 663                  0.67                         0.667
# 129                  0.67                         0.667
# 128                  0.67                         0.667
# 287                  0.67                         0.667
# 286                  0.67                         0.667
# 895                  0.67                         0.667
# 1052                 1.33                         0.667
# 641                  0.67                         0.667
# 796                  0.67                         0.667
# 789                  0.67                         0.667
# 685                  0.67                         0.667
# 894                  0.67                         0.667
# 731                  0.67                         0.667
#
#       expected_number_of_edges   p_value
# 580                        0.0  0.000005
# 595                        0.0  0.000005
# 596                        0.0  0.000005
# 1050                       0.0  0.000005
# 1051                       0.0  0.000006
# 1054                       0.0  0.000006
# 199                        0.0  0.000091
# 947                        0.0  0.000110
# 832                        0.0  0.000170
# 187                        0.0  0.000210
# 232                        0.0  0.000220
# 701                        0.0  0.000220
# 785                        0.0  0.000240
# 617                        0.0  0.000240
# 610                        0.0  0.000260
# 712                        0.0  0.000260
# 581                        0.0  0.000270
# 344                        0.0  0.000270
# 172                        0.0  0.000270
# 355                        0.0  0.000270
# 702                        0.0  0.000280
# 799                        0.0  0.000280
# 861                        0.0  0.000280
# 134                        0.0  0.000280
# 126                        0.0  0.000280
# 825                        0.0  0.000280
# 624                        0.0  0.000290
# 593                        0.0  0.000290
# 1048                       0.0  0.000300
# 728                        0.0  0.000310
# 509                        0.0  0.000310
# 798                        0.0  0.000330
# 136                        0.0  0.000330
# 855                        0.0  0.000330
# 797                        0.0  0.000330
# 341                        0.0  0.000330
# 635                        0.0  0.000330
# 340                        0.0  0.000330
# 637                        0.0  0.000330
# 638                        0.0  0.000330
# 911                        0.0  0.000350
# 862                        0.0  0.000350
# 597                        0.0  0.000350
# 788                        0.0  0.000350
# 707                        0.0  0.000360
# 284                        0.0  0.000360
# 657                        0.0  0.000360
# 663                        0.0  0.000360
# 129                        0.0  0.000360
# 128                        0.0  0.000360
# 287                        0.0  0.000360
# 286                        0.0  0.000360
# 895                        0.0  0.000370
# 1052                       0.0  0.000370
# 641                        0.0  0.000370
# 796                        0.0  0.000380
# 789                        0.0  0.000380
# 685                        0.0  0.000380
# 894                        0.0  0.000410
# 731                        0.0  0.000410

# %%
all_combo_genes = set("|".join(combo_df.uniq_items.str.replace("Input_", "").values).split("|"))

# %%
len(all_combo_genes)
# Out:
# 372

# %%
get_ppi_score(all_combo_genes)
# Out:
# 372	1322	7.11	0.456	432	0.0
#   number_of_nodes number_of_edges average_node_degree  \
# 0             372            1322                7.11
#
#   local_clustering_coefficient expected_number_of_edges p_value  \
# 0                        0.456                      432     0.0
#
#                                                combo
# 0  AP3M2|NOTCH4|TRPM1|ZRANB3|TRNT1|LDLR|CEP290|SP...

# %%
ppi_df = pd.concat(list(map(get_ppi_score, combo_df.uniq_items.str.replace("Input_", "").str.split("|"))))

# %%
ppi_df["p_value"] = ppi_df.p_value.astype(float)

# %%
ppi_df.loc[ppi_df.p_value<0.05]
# Out:
#    number_of_nodes number_of_edges average_node_degree  \
# 0                3               1                0.67
# 0                3               1                0.67
# 0                3               1                0.67
# 0                3               1                0.67
# 0                3               2                1.33
# ..             ...             ...                 ...
# 0                3               1                0.67
# 0                3               1                0.67
# 0                3               1                0.67
# 0                3               1                0.67
# 0                3               1                0.67
#
#    local_clustering_coefficient expected_number_of_edges  p_value  \
# 0                         0.667                        0   0.0498
# 0                         0.667                        0   0.0105
# 0                         0.667                        0   0.0345
# 0                         0.667                        0   0.0252
# 0                         0.667                        0   0.0083
# ..                          ...                      ...      ...
# 0                         0.667                        0   0.0342
# 0                         0.667                        0   0.0350
# 0                         0.667                        0   0.0335
# 0                         0.667                        0   0.0256
# 0                         0.667                        0   0.0330
#
#                    combo
# 0       DNAH5|DNAJC6|TTN
# 0       MYH8|SCN11A|SPTB
# 0        MYH13|SCN9A|TTN
# 0      KIF26A|OBSCN|RYR1
# 0         KCNQ1|RYR1|TTN
# ..                   ...
# 0   HOXB1|UGT1A1|UGT1A10
# 0   HOXB1|UGT1A10|UGT1A6
# 0   HOXB1|UGT1A10|UGT1A8
# 0   HOXB1|UGT1A10|UGT1A3
# 0   HOXB1|UGT1A10|UGT1A7
#
# [373 rows x 7 columns]
