# %%
import pandas as pd

# %%
df = pd.read_csv("/data6/deepro/ukb_bmi/3_characterization/data/combos_in_cohort/british/test_cohort.csv")

# %%
df.loc[df.mean_bmi>29]
# Out:
#                                   uniq_items  \
# 2                  Input_ABCA13|Input_DDX60L
# 5                    Input_RABL6|Input_STIP1
# 6                  Input_COL24A1|Input_STIP1
# 8                      Input_HYDIN|Input_PIR
# 14                 Input_COL4A2|Input_IGFBP1
# ...                                      ...
# 1822  Input_HOXB1|Input_UGT1A1|Input_UGT1A10
# 1823  Input_HOXB1|Input_UGT1A10|Input_UGT1A6
# 1824  Input_HOXB1|Input_UGT1A10|Input_UGT1A8
# 1825  Input_HOXB1|Input_UGT1A10|Input_UGT1A3
# 1826  Input_HOXB1|Input_UGT1A10|Input_UGT1A7
#
#                                           combo_samples  \
# 2     1491563|1497820|1719539|2012612|2905705|311145...
# 5                                               2807522
# 6                                       5027384|5982718
# 8                                               1777517
# 14                              1230995|1261328|2898229
# ...                                                 ...
# ...

# %%
df.sort_values("mean_bmi", ascending=False).head(50)
# Out:
#                                   uniq_items  \
# 459                   Input_KIF5C|Input_RFC1
# 227                Input_ALDH1L2|Input_TRAF4
# 956        Input_CFTR|Input_RYR1|Input_TRNT1
# 260                 Input_CACNA1A|Input_RNMT
# 8                      Input_HYDIN|Input_PIR
# 18                   Input_DLEC1|Input_PREX2
# 469                    Input_RGS9|Input_VSX1
# 5                    Input_RABL6|Input_STIP1
# 389                   Input_AMN|Input_ZNF648
# 836   Input_ATP2C2|Input_ATP7B|Input_SLC26A1
# 915      Input_ABCA4|Input_ATP7B|Input_SYNE1
# 122                 Input_RLN3|Input_SLC20A2
# 948       Input_ABCC1|Input_ATP7B|Input_RYR3
# 591              Input_SLC26A8|Input_SOSTDC1
# 639                   Input_IVD|Input_PCDHB5
# 368                   Input_ATF1|Input_ITIH2
# 132                 Input_CYP7B1|Input_TULP3
# 378             Input_FERD3L|Input_KIDINS220
# 714         Input_DNAH3|Input_LDLR|Input_TTN
# 55                   Input_C1QTNF4|Input_LY9
# ...
