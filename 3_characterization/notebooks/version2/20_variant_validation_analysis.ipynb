# %%
import os
import pandas as pd
from functools import reduce

# %%
combo_info_df = pd.read_csv("/data6/deepro/ukb_bmi/3_characterization/data/archive/combos_in_cohort/british/test_cohort.csv")

combo_files = [
    "/data6/deepro/ukb_bmi/2_rarecomb/data/british/combo2.csv",
    "/data6/deepro/ukb_bmi/2_rarecomb/data/british/combo3.csv"
]

# %%
combo_df = pd.concat([pd.read_csv(cf, usecols=["uniq_items", "Case_Samples", "Control_Samples"]) for cf in combo_files])

# %%
combo_info_df = combo_info_df.merge(combo_df, on="uniq_items")

# %%
combo_genes = set("|".join(combo_info_df.uniq_items.str.replace("Input_", "").values).split("|"))
combo_samples = set("|".join(combo_info_df.combo_samples.fillna("").values).split("|"))
combo_case_samples = set("|".join(combo_info_df.Case_Samples.values).split("|"))

# %%
def get_vtype_df(block_df, combo_genes, combo_samples, combo_case_samples):
    # select lof and deleterious missense variants
    block_df = block_df.loc[(block_df.lof==True)|(block_df.splice_lof==True)|((block_df.missense==True)&(block_df.del_score>4))]
    block_df["samples"] = block_df.samples.str.split(",")
    block_df = block_df.explode("samples")
    block_df = block_df.loc[(block_df.samples.isin(combo_samples.union(combo_case_samples))) & (block_df.gene.isin(combo_genes))]
    return block_df

# %%
vcfs_per_chrm = {
    "chr1": 97, "chr2": 71, "chr3": 56, "chr4": 39, "chr5": 43, "chr6": 48, 
    "chr7": 47, "chr8": 35, "chr9": 42, "chr10": 40, "chr11": 57, "chr12": 52, 
    "chr13": 18, "chr14": 30, "chr15": 34, "chr16": 47, "chr17": 56, "chr18": 16, 
    "chr19": 65, "chr20": 25, "chr21": 11, "chr22": 23, "chrX": 24, "chrY": 1
}
annot_table_dir = "/data6/deepro/ukb_bmi/0_data_preparation_and_download/exome_annot/data/annot_tables_vep109"

cohort_df = pd.DataFrame()
for chr_num in [f"chr{i}" for i in range(1,23)] + ["chrX", "chrY"]:
    print(chr_num)
    chr_file_num = vcfs_per_chrm[chr_num]
    for filei in range(chr_file_num):
        block_file = os.path.join(annot_table_dir, f"{chr_num}", f"block_{filei}.tsv.gz")
        block_df = pd.read_csv(block_file, sep="\t", index_col=0)
        block_df = get_vtype_df(block_df, combo_genes, combo_samples, combo_case_samples)
        cohort_df = pd.concat((cohort_df, block_df))
# Out:
# chr1
# /tmp/ipykernel_18662/4015882037.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_df["samples"] = block_df.samples.str.split(",")
# /tmp/ipykernel_18662/4015882037.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_df["samples"] = block_df.samples.str.split(",")
# /tmp/ipykernel_18662/4015882037.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# cohort_df["variants"] = cohort_df.locus + "_" + cohort_df.alleles

# %%
combo_info_df = combo_info_df.fillna("")

# %%
def get_samples_with_same_variants(ser, cohort_df, vtype="locus"):
    genes = ser.uniq_items.replace("Input_", "").split("|")
    case_samples = set(ser.Case_Samples.split("|"))
    all_samples = set(ser.combo_samples.split("|"))
    other_samples = all_samples.difference(case_samples)
    cohort_case_df = cohort_df.loc[cohort_df.samples.isin(case_samples)]
    variants_by_gene = [set(cohort_case_df.loc[cohort_case_df.gene==g, vtype].values) for g in genes]
    cohort_other_df = cohort_df.loc[cohort_df.samples.isin(other_samples)]
    # get gene wise cohort samples who contain at least one of the case sample variants
    cohort_samples_w_similar_variants = [set(cohort_other_df.loc[(cohort_other_df.gene==g) & (cohort_other_df[vtype].isin(v)), "samples"].values) for g,v in zip(genes, variants_by_gene)]
    cohort_samples_w_same_variants = reduce(lambda x,y: x.intersection(y), cohort_samples_w_similar_variants)
    cohort_samples_w_different_variants = other_samples.difference(cohort_samples_w_same_variants)
    return pd.Series({"cohort_samples_same_variants": "|".join(cohort_samples_w_same_variants), "cohort_samples_other_variants": "|".join(cohort_samples_w_different_variants)})

# %%
combo_info_df = combo_info_df.merge(combo_info_df.apply(get_samples_with_same_variants, args=(cohort_df, "locus"), axis=1), left_index=True, right_index=True)

# %%
pheno_df = pd.read_csv("/data6/deepro/ukb_bmi/0_data_preparation_and_download/phenotype/data/bmi_processed/filtered_bmi_info.csv.gz",
                       usecols=["sample_names", "bmi"], dtype={"sample_names": str, "bmi": float})

# %%
combo_info_df
# Out:
#                                   uniq_items  \
# 0                    Input_BMPR1B|Input_SHC2
# 1                     Input_BCHE|Input_TRPV4
# 2                  Input_ABCA13|Input_DDX60L
# 3                    Input_MYH14|Input_NR1D1
# 4                    Input_ADAM19|Input_MMUT
# ...                                      ...
# 1829       Input_CPT1B|Input_DRG1|Input_SFI1
# 1830   Input_ACAP3|Input_SLC7A8|Input_TAS1R3
# 1831      Input_F5|Input_NBEAL2|Input_SPINK8
# 1832     Input_GHDC|Input_KRTAP2-3|Input_TTN
# 1833  Input_CYP4F22|Input_ZNF490|Input_ZNF69
#
#                                           combo_samples  \
# 0               1879013|2426902|2652086|2971759|5077153
# 1     1030730|1052768|1454309|2473967|3420426|465704...
# 2     1491563|1497820|1719539|2012612|2905705|311145...
# 3                                               1313174
# 4                                               1264809
# ...                                                 ...
# 1829
# 1830
# ...

# %%
same_var_samples = set("|".join(combo_info_df.cohort_samples_same_variants.values).split("|"))
diff_var_samples = set("|".join(combo_info_df.cohort_samples_other_variants.values).split("|"))

# %%
pheno_sv_df = pheno_df.loc[pheno_df.sample_names.isin(same_var_samples)]
pheno_dv_df = pheno_df.loc[pheno_df.sample_names.isin(diff_var_samples)]

# %%
cohort_df
# Out:
#               locus alleles     gene    lof  missense  splice_lof  splice  \
# 2748    chr1:999540     C_G     HES4  False      True       False   False
# 2753    chr1:999557     G_C     HES4  False      True       False   False
# 2753    chr1:999557     G_C     HES4  False      True       False   False
# 2753    chr1:999557     G_C     HES4  False      True       False   False
# 2753    chr1:999557     G_C     HES4  False      True       False   False
# ...             ...     ...      ...    ...       ...         ...     ...
# 1953  chrX:49231680     C_G  CACNA1F  False      True       False    True
# 1953  chrX:49231680     C_G  CACNA1F  False      True       False    True
# 1953  chrX:49231680     C_G  CACNA1F  False      True       False    True
# 1953  chrX:49231680     C_G  CACNA1F  False      True       False    True
# 1973  chrX:49231813     G_A  CACNA1F  False      True       False   False
#
#       del_score  samples
# 2748        5.0  2812594
# 2753        6.0  1294759
# ...

# %%
combo_info_df
# Out:
#                                   uniq_items  \
# 0                    Input_BMPR1B|Input_SHC2
# 1                     Input_BCHE|Input_TRPV4
# 2                  Input_ABCA13|Input_DDX60L
# 3                    Input_MYH14|Input_NR1D1
# 4                    Input_ADAM19|Input_MMUT
# ...                                      ...
# 1829       Input_CPT1B|Input_DRG1|Input_SFI1
# 1830   Input_ACAP3|Input_SLC7A8|Input_TAS1R3
# 1831      Input_F5|Input_NBEAL2|Input_SPINK8
# 1832     Input_GHDC|Input_KRTAP2-3|Input_TTN
# 1833  Input_CYP4F22|Input_ZNF490|Input_ZNF69
#
#                                           combo_samples  \
# 0               1879013|2426902|2652086|2971759|5077153
# 1     1030730|1052768|1454309|2473967|3420426|465704...
# 2     1491563|1497820|1719539|2012612|2905705|311145...
# 3                                               1313174
# 4                                               1264809
# ...                                                 ...
# 1829
# 1830
# ...

# %%
from scipy.stats import kstest,ttest_ind

# %%
pheno_sv_df.bmi.describe()
# Out:
# count    323.000000
# mean      27.240954
# std        5.001718
# min       16.659700
# 25%       24.198200
# 50%       26.323600
# 75%       29.020950
# max       53.551900
# Name: bmi, dtype: float64

# %%
pheno_dv_df.bmi.describe()
# Out:
# count    3672.000000
# mean       28.501814
# std         5.357681
# min        16.080400
# 25%        24.866675
# 50%        27.732550
# 75%        31.173200
# max        68.129900
# Name: bmi, dtype: float64

# %%
ttest_ind(pheno_sv_df.bmi, pheno_dv_df.bmi, alternative="less")
# Out:
# TtestResult(statistic=-4.076105129857056, pvalue=2.3343678936046364e-05, df=3993.0)

# %%
kstest(pheno_sv_df.bmi, pheno_dv_df.bmi, alternative="greater")
# Out:
# /data6/deepro/miniconda3/envs/dnanexus/lib/python3.11/site-packages/scipy/stats/_stats_py.py:9081: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   return ks_2samp(xvals, yvals, alternative=alternative, method=method)
# KstestResult(statistic=0.14671482628138974, pvalue=2.5313332925852467e-06, statistic_location=27.0754, statistic_sign=1)

# %%
pheno_df
# Out:
#        sample_names       bmi
# 0           1000028  25.50385
# 1           1000045  23.71090
# 2           1000104  30.85940
# 3           1000171  30.92310
# 4           1000196  19.57480
# ...             ...       ...
# 499193      6024948  47.22080
# 499194      6025016  26.56900
# 499195      6025119  30.07590
# 499196      6025181  26.49910
# 499197      6025208  23.99740
#
# [499198 rows x 2 columns]

# %%
pheno_sv_df.bmi.describe()
# Out:
# count    263.000000
# mean      27.074162
# std        4.796791
# min       16.215500
# 25%       23.746500
# 50%       26.613700
# 75%       29.530900
# max       46.573900
# Name: bmi, dtype: float64

# %%
pheno_dv_df.bmi.describe()
# Out:
# count    3929.000000
# mean       28.564296
# std         5.315094
# min        15.105600
# 25%        24.849100
# 50%        27.735000
# 75%        31.360100
# max        61.935500
# Name: bmi, dtype: float64

# %%
combo_info_df
# Out:
#                                uniq_items  \
# 0                   Input_ASS1|Input_HELB
# 1                Input_SUSD2|Input_ZNF124
# 2                 Input_DCLK1|Input_PCSK7
# 3                  Input_IFRD2|Input_KRT2
# 4                  Input_CPOX|Input_PDE5A
# ..                                    ...
# 663    Input_SEMA4G|Input_TENM4|Input_TTN
# 664    Input_AMDHD2|Input_CEMP1|Input_GSS
# 665      Input_PAH|Input_PXN|Input_VPS33A
# 666  Input_HOXD11|Input_HOXD12|Input_MYH3
# 667  Input_ABCA4|Input_BTN2A1|Input_H4C12
#
#                                          combo_samples  \
# 0    1124630|1547241|1997059|2404794|3013533|412695...
# 1
# 2
# 3                                              5213529
# 4                                      1441106|3569442
# ..                                                 ...
# 663                                    3144114|4949660
# 664                            2115170|3358263|3841155
# 665            1413385|2030452|2778667|5278619|5874984
# ...

# %%
cohort_df
# Out:
#               locus alleles    gene    lof  missense  splice_lof  splice  \
# 1874  chr1:16022641     C_T  CLCNKA  False      True       False   False
# 1885  chr1:16022674     C_T  CLCNKA   True     False       False   False
# 1888  chr1:16022693     G_A  CLCNKA  False      True       False   False
# 1904  chr1:16023832     C_T  CLCNKA  False      True       False   False
# 1905  chr1:16023833     G_A  CLCNKA  False      True       False   False
# ...             ...     ...     ...    ...       ...         ...     ...
# 1229  chrX:18948809     T_C   PHKA2  False      True       False   False
# 1230  chrX:18948810    G_GA   PHKA2   True     False       False   False
# 1247  chrX:18951263     C_T   PHKA2  False      True       False   False
# 1249  chrX:18952522     C_T   PHKA2  False      True       False   False
# 1255  chrX:18954289     C_T   PHKA2  False      True       False   False
#
#       del_score  samples
# 1874        5.0  3973868
# 1885        0.0  1600398
# ...

# %%
# case_samples per combo
# get the variants of genes in these cases
# per combo check the samples other than case samples who have these variants
