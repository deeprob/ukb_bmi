# %% [markdown]
# # Initiate Spark and Hail

# %%
# Running this cell will output a red-colored message- this is expected.
# The 'Welcome to Hail' message in the output will indicate that Hail is ready to use in the notebook.

from pyspark.sql import SparkSession
import hail as hl

builder = (
    SparkSession
    .builder
    .enableHiveSupport()
)
spark = builder.getOrCreate()
hl.init(sc=spark.sparkContext)
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/cluster/dnax/jars/dnanexus-api-0.1.0-SNAPSHOT-jar-with-dependencies.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/cluster/spark/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2023-08-30 15:40:06.670 WARN  NativeCodeLoader:60 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2023-08-30 15:40:07.002 WARN  Utils:69 - Service 'sparkDriver' could not bind on port 42000. Attempting port 42001.
# 2023-08-30 15:40:07.746 WARN  Utils:69 - Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 43000. Attempting port 43001.
# 2023-08-30 15:40:08.000 WARN  MetricsReporter:84 - No metrics configured for reporting
# 2023-08-30 15:40:08.002 WARN  LineProtoUsageReporter:48 - Telegraf configurations: url [metrics.push.telegraf.hostport], user [metrics.push.telegraf.user] or password [metrics.push.telegraf.password] missing.
# 2023-08-30 15:40:08.002 WARN  MetricsReporter:117 - metrics.scraping.httpserver.port
# pip-installed Hail requires additional configuration options in Spark referring
#   to the path to the Hail Python module directory HAIL_DIR,
#   e.g. /path/to/python/site-packages/hail:
#     spark.jars=HAIL_DIR/backend/hail-all-spark.jar
#     spark.driver.extraClassPath=HAIL_DIR/backend/hail-all-spark.jar
#     spark.executor.extraClassPath=./hail-all-spark.jar
# log4j: Parsing for [root] with value=[INFO, logfile].
# log4j: Level token is [INFO].
# log4j: Category root set to INFO
# log4j: Parsing appender named "logfile".
# log4j: Parsing layout options for "logfile".
# log4j: Setting property [conversionPattern] to [%d{yyyy-MM-dd HH:mm:ss.SSS} %c{1}: %p: %m%n].
# log4j: End of parsing for "logfile".
# log4j: Setting property [append] to [false].
# log4j: Setting property [threshold] to [INFO].
# log4j: Setting property [file] to [/opt/notebooks/hail-20230830-1540-0.2.116-cd64e0876c94.log].
# log4j: setFile called: /opt/notebooks/hail-20230830-1540-0.2.116-cd64e0876c94.log, false
# log4j: setFile ended
# log4j: Parsed "logfile" options.
# log4j: Parsing for [Hail] with value=[INFO, HailSocketAppender].
# log4j: Level token is [INFO].
# log4j: Category Hail set to INFO
# log4j: Parsing appender named "HailSocketAppender".
# log4j: Parsed "HailSocketAppender" options.
# log4j: Handling log4j.additivity.Hail=[null]
# log4j: Finished configuring.
# Running on Apache Spark version 3.2.3
# SparkUI available at http://ip-10-60-62-67.eu-west-2.compute.internal:8081
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.116-cd64e0876c94
# LOGGING: writing to /opt/notebooks/hail-20230830-1540-0.2.116-cd64e0876c94.log

# %% [markdown]
# # Import vcf files in batches and store them as tables

# %%
import os

vcf_dir = "/mnt/project/Bulk/Exome sequences/Population level exome OQFE variants, pVCF format - final release/"
chr_num = "1"
vcf_files = sorted(["file://" + os.path.join(vcf_dir, fp) for fp in os.listdir(vcf_dir) if (f"_c{chr_num}_" in fp and fp.endswith("vcf.gz"))])

# %%
# Create database in DNAX
db_name = f"exome_chr{chr_num}"
stmt = f"CREATE DATABASE IF NOT EXISTS {db_name} LOCATION 'dnax://'"
print(stmt)
spark.sql(stmt).show()

# Create mt tables in batches and write to the database
# Out:
# CREATE DATABASE IF NOT EXISTS exome_chr1 LOCATION 'dnax://'
# ++
# ||
# ++
# ++

# %%
# Create mt table for each file and write to the database
import time
import dxpy
import logging

logging.basicConfig(filename=f"chr{chr_num}_mt.log", level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p')

# Find database ID of newly created database using dxpy method
db_uri = dxpy.find_one_data_object(name=f"{db_name}".lower(), classname="database")['id']

for i,vcf in enumerate(vcf_files[48:]):
    time_start = time.time()
    mt = hl.import_vcf(
        vcf, force_bgz=True, reference_genome="GRCh38", array_elements_required=False, block_size=512
    )
    mt_name = f"block_{i+48}.mt"
    url = f"dnax://{db_uri}/{mt_name}" # Note: the dnax url must follow this format to properly save MT to DNAX
    mt.write(url, overwrite=True) # Note: output should describe size of MT (i.e. number of rows, columns, partitions) 
    time_end = time.time()
    time_taken = (time_end - time_start)/60
    logging.info(f"Time to create block {i+48}: {time_taken} mins\n")
# Out:
# 2023-08-30 15:40:45.734 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 15:44:54.507 Hail: INFO: Coerced sorted VCF - no additional import work to do
# 2023-08-30 16:00:55.479 Hail: INFO: wrote matrix table with 22139 rows and 469835 columns in 41 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_48.mt
# 2023-08-30 16:01:19.842 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 16:05:16.803 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693411518534] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 16:20:51.887 Hail: INFO: wrote matrix table with 20514 rows and 469835 columns in 38 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_49.mt
# 2023-08-30 16:21:16.349 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 16:25:48.337 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693412749853] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 16:42:55.703 Hail: INFO: wrote matrix table with 24538 rows and 469835 columns in 51 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_50.mt
# 2023-08-30 16:43:20.640 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 16:47:51.207 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693414073068] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 17:04:55.835 Hail: INFO: wrote matrix table with 24423 rows and 469835 columns in 49 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_51.mt
# 2023-08-30 17:05:20.314 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 17:09:50.428 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693415391891] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 17:26:19.127 Hail: INFO: wrote matrix table with 19825 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_52.mt
# 2023-08-30 17:26:43.135 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 17:30:57.353 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693416658866] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 17:47:31.741 Hail: INFO: wrote matrix table with 23693 rows and 469835 columns in 49 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_53.mt
# 2023-08-30 17:47:56.492 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 17:52:10.565 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693417932358] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 18:07:57.694 Hail: INFO: wrote matrix table with 24545 rows and 469835 columns in 48 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_54.mt
# 2023-08-30 18:08:22.942 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 18:12:24.623 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693419146051] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 18:27:04.107 Hail: INFO: wrote matrix table with 22620 rows and 469835 columns in 45 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_55.mt
# 2023-08-30 18:27:28.803 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 18:31:54.605 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693420316102] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 18:50:30.048 Hail: INFO: wrote matrix table with 23930 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_56.mt
# 2023-08-30 18:50:53.917 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 18:55:15.744 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693421717535] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 19:13:14.590 Hail: INFO: wrote matrix table with 24278 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_57.mt
# 2023-08-30 19:13:38.685 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 19:18:07.648 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693423089076] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 19:36:05.107 Hail: INFO: wrote matrix table with 24369 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_58.mt
# 2023-08-30 19:36:29.473 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 19:41:01.925 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693424463346] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 19:58:57.340 Hail: INFO: wrote matrix table with 24181 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_59.mt
# 2023-08-30 19:59:20.754 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 20:04:11.800 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693425853266] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 20:20:12.354 Hail: INFO: wrote matrix table with 24845 rows and 469835 columns in 48 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_60.mt
# 2023-08-30 20:20:36.311 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 20:27:19.313 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693427240786] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 20:46:12.497 Hail: INFO: wrote matrix table with 25237 rows and 469835 columns in 52 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_61.mt
# 2023-08-30 20:46:37.116 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 20:51:13.627 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693428675094] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 21:08:56.101 Hail: INFO: wrote matrix table with 24723 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_62.mt
# 2023-08-30 21:09:20.429 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 21:13:38.813 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693430020215] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 21:29:16.023 Hail: INFO: wrote matrix table with 23506 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_63.mt
# 2023-08-30 21:29:40.248 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 21:33:43.139 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693431224569] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 21:48:42.988 Hail: INFO: wrote matrix table with 23622 rows and 469835 columns in 44 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_64.mt
# 2023-08-30 21:49:08.899 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 21:53:06.621 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693432388301] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 22:08:50.579 Hail: INFO: wrote matrix table with 24520 rows and 469835 columns in 44 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_65.mt
# 2023-08-30 22:09:15.502 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 22:13:31.140 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693433612531] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 22:28:57.764 Hail: INFO: wrote matrix table with 23426 rows and 469835 columns in 48 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_66.mt
# 2023-08-30 22:29:21.668 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 22:33:35.917 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693434817341] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 22:49:19.013 Hail: INFO: wrote matrix table with 24608 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_67.mt
# 2023-08-30 22:49:44.202 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 22:53:54.000 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693436035455] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 23:09:34.065 Hail: INFO: wrote matrix table with 24679 rows and 469835 columns in 48 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_68.mt
# 2023-08-30 23:09:58.452 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 23:14:20.764 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693437262150] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 23:29:41.700 Hail: INFO: wrote matrix table with 24584 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_69.mt
# 2023-08-30 23:30:09.711 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 23:34:19.404 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693438461093] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-30 23:50:03.089 Hail: INFO: wrote matrix table with 24065 rows and 469835 columns in 44 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_70.mt
# 2023-08-30 23:50:44.522 Hail: INFO: scanning VCF for sortedness...
# 2023-08-30 23:55:09.789 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693439711235] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 00:10:47.237 Hail: INFO: wrote matrix table with 24439 rows and 469835 columns in 44 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_71.mt
# 2023-08-31 00:11:11.376 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 00:15:50.623 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693440952051] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 00:32:15.664 Hail: INFO: wrote matrix table with 24569 rows and 469835 columns in 43 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_72.mt
# 2023-08-31 00:32:39.992 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 00:36:57.364 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693442218871] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 00:52:16.954 Hail: INFO: wrote matrix table with 24470 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_73.mt
# 2023-08-31 00:52:57.892 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 00:57:26.704 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693443448134] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 01:13:24.196 Hail: INFO: wrote matrix table with 25780 rows and 469835 columns in 53 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_74.mt
# 2023-08-31 01:13:48.627 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 01:18:24.754 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693444706188] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 01:34:05.257 Hail: INFO: wrote matrix table with 23713 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_75.mt
# 2023-08-31 01:34:31.097 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 01:39:03.514 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693445944950] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 01:54:48.905 Hail: INFO: wrote matrix table with 24316 rows and 469835 columns in 45 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_76.mt
# 2023-08-31 01:55:33.000 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 01:59:58.722 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693447200129] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 02:15:14.698 Hail: INFO: wrote matrix table with 23294 rows and 469835 columns in 46 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_77.mt
# 2023-08-31 02:15:39.405 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 02:20:12.382 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693448413812] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 02:35:20.560 Hail: INFO: wrote matrix table with 23640 rows and 469835 columns in 45 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_78.mt
# 2023-08-31 02:36:00.940 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 02:40:54.467 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693449655885] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 02:59:36.238 Hail: INFO: wrote matrix table with 24281 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_79.mt
# 2023-08-31 03:00:00.525 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 03:04:40.134 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693451081557] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 03:19:51.794 Hail: INFO: wrote matrix table with 23881 rows and 469835 columns in 46 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_80.mt
# 2023-08-31 03:20:18.154 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 03:25:12.067 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693452313505] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 03:41:33.902 Hail: INFO: wrote matrix table with 24475 rows and 469835 columns in 46 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_81.mt
# 2023-08-31 03:41:58.960 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 03:46:54.976 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693453616383] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 04:04:13.800 Hail: INFO: wrote matrix table with 24473 rows and 469835 columns in 50 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_82.mt
# 2023-08-31 04:04:37.730 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 04:09:06.874 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693454948285] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 04:24:58.769 Hail: INFO: wrote matrix table with 24427 rows and 469835 columns in 44 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_83.mt
# 2023-08-31 04:25:23.756 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 04:29:48.552 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693456189930] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 04:45:22.029 Hail: INFO: wrote matrix table with 24318 rows and 469835 columns in 48 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_84.mt
# 2023-08-31 04:45:46.503 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 04:49:57.954 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693457399362] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 05:05:27.256 Hail: INFO: wrote matrix table with 23878 rows and 469835 columns in 45 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_85.mt
# 2023-08-31 05:05:52.264 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 05:12:50.268 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693458771654] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 05:29:54.177 Hail: INFO: wrote matrix table with 23912 rows and 469835 columns in 54 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_86.mt
# 2023-08-31 05:30:20.252 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 05:35:03.122 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693460104531] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 05:51:13.989 Hail: INFO: wrote matrix table with 23939 rows and 469835 columns in 52 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_87.mt
# 2023-08-31 05:51:38.507 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 05:56:03.005 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693461364423] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 06:11:41.014 Hail: INFO: wrote matrix table with 23389 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_88.mt
# 2023-08-31 06:12:10.105 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 06:17:04.359 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693462625786] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 06:32:58.143 Hail: INFO: wrote matrix table with 24146 rows and 469835 columns in 51 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_89.mt
# 2023-08-31 06:33:27.233 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 06:37:59.409 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693463880847] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 06:53:27.564 Hail: INFO: wrote matrix table with 23867 rows and 469835 columns in 47 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_90.mt
# 2023-08-31 06:53:52.503 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 06:58:19.688 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693465101108] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 07:13:34.122 Hail: INFO: wrote matrix table with 23859 rows and 469835 columns in 44 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_91.mt
# 2023-08-31 07:14:00.125 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 07:18:36.330 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693466317753] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 07:34:10.177 Hail: INFO: wrote matrix table with 23409 rows and 469835 columns in 42 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_92.mt
# 2023-08-31 07:34:34.999 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 07:39:05.079 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693467546502] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 07:53:56.117 Hail: INFO: wrote matrix table with 23072 rows and 469835 columns in 43 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_93.mt
# 2023-08-31 07:54:20.895 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 07:59:09.126 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693468750513] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 08:14:00.929 Hail: INFO: wrote matrix table with 24037 rows and 469835 columns in 54 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_94.mt
# 2023-08-31 08:14:25.304 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 08:18:00.648 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693469882052] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 08:27:35.168 Hail: INFO: wrote matrix table with 7629 rows and 469835 columns in 17 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_95.mt
# 2023-08-31 08:27:59.624 Hail: INFO: scanning VCF for sortedness...
# 2023-08-31 08:32:39.759 Hail: INFO: Coerced sorted VCF - no additional import work to do
# [1693470761186] ResourceNotFound: The specified database file could not be found.. Code: 404 Request ID:
# 2023-08-31 08:48:33.054 Hail: INFO: wrote matrix table with 23647 rows and 469835 columns in 49 partitions to dnax://database-GYg1k8jJX0KKFBYGV4V3jpxZ/block_96.mt

# %%
# %%bash
# dx upload "chr1_mt.log" --path "exome_annot/annot_run/notebooks/chr1/"
# Out:
# ID                          file-GYj57jjJX0K2JYp899y46ypp
# Class                       file
# Project                     project-GQpgZf8JX0KKbFBGK9yff4Zg
# Folder                      /exome_annot/annot_run/notebooks/chr1
# Name                        chr1_mt.log
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu Aug 31 08:48:35 2023
# Created by                  dzb5732
#  via the job                job-GYgbgFQJX0K7Jv1G8QG1FXVk
# Last modified               Thu Aug 31 08:48:37 2023
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
